# %% [markdown]
# # (Almost) all the activation functions, illustrated
#
# _This notebook was originally created by Rob Leckeby at Agile Sceintific._
#
# Some activation functions are listed below, then a function to plot them all with their derivatives.
#
# Credit to [Dishashree Gupta](https://www.analyticsvidhya.com/blog/2020/01/fundamentals-deep-learning-activation-functions-when-to-use-them/) for the list of functions.

# %% [markdown]
# ## The sigmoid function
#
# A basic, classical nonlinear function which effectively implements logistic regression in a perceptron.

# %%
import numpy as np


def sigmoid(z, *, derivative=False):
    """
    The sigmoid, or logistic function.
    """
    if derivative:
        # In the backward case, z is really sigmoid(z).
        return z * (1 - z)
    return 1 / (1 + np.exp(-z))

# %% [markdown]
# In a neural network, we have in incoming signal `x`, over which we compute a linear function, `z = wx + b`, where `w` is a set of weights and `b` a set of biases on a given set of neurons.
#
# We don't need `x`, `b` and `w`, we can just focus on what happens to the computed signal `wx + b` when it passed through our nonlinear function. So let's define `z`, a range of possible values for the computed neural signal:

# %%
z = np.linspace(-5, 5, 400)

# %% [markdown]
# Now we can compute the activation `a` and its derivative `a_`. Now, although the symbolic definition of the derivative is `sigmoid(z) * (1 - sigmoid(z)`, we defined it as `z * (1 - z)`, because when we do this calculation inside a neural network, the derivative is being computed on `a`, the result of `sigmoid(z)`. So we pass `a` to the function when we calculate the derivative.

# %%
a = sigmoid(z)
a_ = sigmoid(a, derivative=True)

# %% [markdown]
# Now we can plot these two arrays:

# %%
import matplotlib.pyplot as plt

def plot(z, a, a_):
    fig, axs = plt.subplots(ncols=2, figsize=(15, 4), sharey=True)
    ys, titles = [a, a_], ['Forward function', 'Derivative']
    for ax, y, title in zip(axs, ys, titles):
        ax.set_title(title)
        ax.plot(z, y, lw=3)
        ax.grid(c='k', alpha=0.1)
        ax.axhline(0, c='k', alpha=0.5)
        ax.axvline(0, c='k', alpha=0.5)

plot(z, a, a_)

# %% [markdown]
# We note that the maximum gradient is quite small (0.25), so activations will get attenuated as they pass through a network using this activation function. This is one of the reasons the `tanh` function became popular.

# %% [markdown]
# ## `tanh`
#
# We could use NumPy to compute this, but we can also use the exponential definition:
#
# $$ \tanh x = \frac{e^{2x} - 1} {e^{2x} + 1} $$

# %%
def tanh(z, *, derivative=False):
    """
    The tanh function and its derivative.
    """
    if derivative:
        return 1 - z**2
    return (np.exp(2 * z) - 1) / (np.exp(2 * z) + 1)

# %%
a = tanh(z)
a_ = tanh(a, derivative=True)

# %%
plot(z, a, a_)

# %% [markdown]
# ---
#
# ## Lots more functions!

# %%
def linear(z, *, alpha=1, derivative=False):
    """
    A simple scaling function.
    """
    if derivative:
        return np.ones_like(z) * alpha
    return alpha * z

def binary_step(z, *, derivative=False):
    """
    The Heaviside function.
    """
    if derivative:
        return np.zeros_like(z)
    return 1 * (z > 0)
    
def relu(z, *, derivative=False):
    """
    Rectified Linear Unit (ReLU) (Hahnloser et al., 2000;
    Jarrett et al., 2009; Nair & Hinton, 2010). Special
    case of LReLU, see below.
    """
    if derivative:
        return 1 * (z > 0)
    return z * (z > 0)

def leaky_relu(z, *, alpha=0.01, derivative=False):
    """
    Leaky ReLU (LReLU). (Maas et al., 2013).
    The ReLU is a special case where alpha = 0.
    """
    if derivative:
        return alpha * (z <= 0) + (z > 0)
    return np.maximum(alpha * z, z) 

def elu(z, *, alpha=1, derivative=False):
    """
    Exponential Linear Unit (ELU) (Clevert et al., 2015).
    """
    if derivative:
        return np.where(z < 0, alpha * np.exp(z), 1)
    return np.where(z < 0, alpha * (np.exp(z) - 1), z)

def swish(z, *, derivative=False):
    """
    SWISH: A self-generated activation function.
    https://arxiv.org/pdf/1710.05941v1.pdf
    Special case of E-Swish, see below.
    """
    if derivative:
        return z * sigmoid(z) + sigmoid(z) * (1 - z * sigmoid(z))
    return z * sigmoid(z)

def eswish(z, *, beta=1, derivative=False):
    """
    Eswish https://arxiv.org/abs/1801.07145
    Eswish is a generalization of Swish,
    multiplied by a parameter beta.
    """
    if derivative:
        return beta * z * sigmoid(z) + sigmoid(z) * (beta - beta * z * sigmoid(z))
    return beta * z * sigmoid(z)

# %% [markdown]
# Let's plot all of these.

# %%
from cycler import cycler

x = np.linspace(-4, 4, 400)
functions = [linear, binary_step, sigmoid, tanh, relu, leaky_relu, elu, eswish]

cyc3 = cycler(color=[u'#1f77b4', u'#ff7f0e', u'#2ca02c'])
props_deriv = {'lw': 2.5, 'ls': '--', 'alpha': 0.67}
props_forward = {'lw': 2.5, 'ls': '-', 'alpha': 1.0}
props_hvlines = {'c': 'k', 'lw': 1.5, 'alpha': 0.3}

fig, axs = plt.subplots(nrows=2, ncols=4, figsize=(16, 8))
fig.suptitle('Activation functions and their derivatives', size=16)

for f, ax in zip(functions, axs.flat):
    ax.set_title(f.__name__.upper().replace('_', ' '))
    
    for d in (False, True):  # Forward and backward functions.
        props = props_deriv if d else props_forward
        if len(kwargs := f.__kwdefaults__) == 1:
            ax.set_prop_cycle(cycler(color=[u'#1f77b4']))
            y = f(x)
            if d:
                y = f(y, derivative=d)
            ax.plot(x, y, label=None, **props)
        else:
            arg, _ = kwargs.keys()
            vals = [1, 1.5, 2] if f is eswish else [0.05, 0.5, 1]
            ax.set_prop_cycle(cyc3)
            for v in vals:
                kwargs.update({arg: v, 'derivative': d})
                y = f(x, **kwargs)
                label = f"{arg}: {v}" if not d else None
                ax.plot(x, y, label=label, **props)
            ax.legend(loc=4)
        
    ax.grid()
    ax.axhline(0, -3, 3, **props_hvlines)
    ax.axvline(0, -3, 3, **props_hvlines)
    ax.set_xlim(-3, 3); ax.set_ylim(-3, 3)            
        
plt.subplots_adjust(hspace=0.4)
plt.show()

# %% [markdown]
# ---
#
# &copy; Matt Hall 2024 and Rob Leckenby 2021, licenced CC BY, please share and re-use

# %% [markdown]
# # **Activation Functions in Deep Learning**

# %% [markdown]
# ## **What are Activation Functions?**
# In artificial neural networks, each neuron forms a weighted sum of its inputs and passes the resulting scalar value through a function referred to as an activation function or transfer function. If a neuron has n inputs $x_1, x_2, ..., x_n$ then the output of a neuron is:
# $$a = g(w_1x_1 + w_2x_2 + w_3x_3 + ... + w_nx_n + b)$$
# The function $g$ is referred to as the activation function. If the function $g$ is taken as the linear function $g(z) = z$ then the neuron performs linear regression or classification. In general $g$ is taken to be a nonlinear function to do nonlinear regression and solve classification problems that are not linearly separable. When $g$ is taken to be a sigmoidal or 's' shaped function varying from 0 to 1 or -1 to 1, the output value of the neuron can be interpreted as a YES/NO answer or binary decision. However saturating activation function can cause the vanishing gradient problem in deep networks. Replacing saturating sigmoidal activation functions with activation functions like ReLU that have larger derivative values allowed deeper networks to be trained for the first time. Non-monotonic and oscillating activation functions that significantly outperform ReLU have since been found. In particular oscillating activation functions improve gradient flow, speedup training and allow single neurons to learn the XOR function like certain human cerebral neurons.
#
# <img src="https://miro.medium.com/v2/resize:fit:1170/1*abHGVMc8bTFVFSvB6ZYaBg.png" width="40%">

# %% [markdown]
# ## **Why Activation Functions are needed?**
# Activation functions are essential in neural networks for the following reasons:
#
# 1. **Introduce Non-Linearity**: They allow networks to learn complex, non-linear relationships in data, which linear models can't capture.
#
# 2. **Enable Deep Learning**: They help in learning hierarchical feature representations, allowing deeper layers to capture more abstract patterns.
#
# 3. **Universal Approximation**: With activation functions, networks can approximate any continuous function, as per the Universal Approximation Theorem.
#
# 4. **Gradient-Based Optimization**: They provide the necessary gradients for training via backpropagation, making learning possible and efficient.
#
# 5. **Biological Inspiration**: They mimic the non-linear activation of biological neurons, adding biological plausibility to artificial models.
#
# 6. **Output Characteristics**: Different activation functions offer various output ranges, suited for specific tasks like classification.

# %% [markdown]
# ### **Code Example**

# %% [markdown]
# #### **Import Required Libraries**

# %%
# !pip install mlxtend
# Out:
# Collecting mlxtend
#   Downloading mlxtend-0.23.4-py3-none-any.whl (1.4 MB)
#      ---------------------------------------- 1.4/1.4 MB 28.6 MB/s eta 0:00:00
# Requirement already satisfied: scipy>=1.2.1 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from mlxtend) (1.15.2)
# Requirement already satisfied: numpy>=1.16.2 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from mlxtend) (2.1.3)
# Requirement already satisfied: pandas>=0.24.2 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from mlxtend) (2.2.3)
# Requirement already satisfied: scikit-learn>=1.3.1 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from mlxtend) (1.6.1)
# Requirement already satisfied: matplotlib>=3.0.0 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from mlxtend) (3.10.1)
# Requirement already satisfied: joblib>=0.13.2 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from mlxtend) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from matplotlib>=3.0.0->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from pandas>=0.24.2->mlxtend) (2025.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from scikit-learn>=1.3.1->mlxtend) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\alvar\onedrive - tajamar\iagen-desarrollo\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.0.0->mlxtend) (1.17.0)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.23.4
# [notice] A new release of pip available: 22.3 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import make_classification
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from keras.optimizers import Adam
from mlxtend.plotting import plot_decision_regions

import warnings
warnings.filterwarnings("ignore")

plt.rcParams["font.family"] = "DeJavu Serif"
plt.rcParams["font.serif"] = "Times New Roman"

# %% [markdown]
# #### **Make a Dataset**

# %%
# Generate a classification dataset
X, y = make_classification(
    n_samples=200, 
    n_features=2, 
    n_informative=2, 
    n_redundant=0,
    n_clusters_per_class=1,
    class_sep=1,
    random_state=32)

# Plot the data
sns.scatterplot(x=X[:, 0], y=X[:, 1], hue=y);

# %% [markdown]
# #### **Neural Network with Linear Activation in the Hidden Layers**

# %%
# Build a neural network with linear activation used in the hidden layers
model = Sequential()

model.add(Dense(128, activation="linear", input_dim=2))
model.add(Dense(128, activation="linear"))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

history = model.fit(X, y, epochs=500, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.5164 - loss: 0.6649 - val_accuracy: 0.7750 - val_loss: 0.6899
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8595 - loss: 0.4501 - val_accuracy: 0.8000 - val_loss: 0.3952
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8287 - loss: 0.4241 - val_accuracy: 0.7750 - val_loss: 0.3963
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8318 - loss: 0.3872 - val_accuracy: 0.7750 - val_loss: 0.4026
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8147 - loss: 0.4077 - val_accuracy: 0.7750 - val_loss: 0.3815
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8505 - loss: 0.3781 - val_accuracy: 0.7750 - val_loss: 0.3904
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8210 - loss: 0.4118 - val_accuracy: 0.7750 - val_loss: 0.4039
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8431 - loss: 0.3595 - val_accuracy: 0.7750 - val_loss: 0.3660
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8235 - loss: 0.4258 - val_accuracy: 0.7750 - val_loss: 0.3837
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7819 - loss: 0.4257 - val_accuracy: 0.7750 - val_loss: 0.3999
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8383 - loss: 0.3940 - val_accuracy: 0.7750 - val_loss: 0.3721
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7751 - loss: 0.4282 - val_accuracy: 0.7750 - val_loss: 0.4295
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8218 - loss: 0.4738 - val_accuracy: 0.7750 - val_loss: 0.3829
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8622 - loss: 0.3361 - val_accuracy: 0.7750 - val_loss: 0.3798
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8501 - loss: 0.4005 - val_accuracy: 0.7750 - val_loss: 0.3901
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8365 - loss: 0.3917 - val_accuracy: 0.7750 - val_loss: 0.3912
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8249 - loss: 0.3821 - val_accuracy: 0.7750 - val_loss: 0.3803
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7959 - loss: 0.4306 - val_accuracy: 0.7750 - val_loss: 0.3851
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8401 - loss: 0.3823 - val_accuracy: 0.7750 - val_loss: 0.4033
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8119 - loss: 0.4554 - val_accuracy: 0.8000 - val_loss: 0.3695
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7993 - loss: 0.4292 - val_accuracy: 0.7750 - val_loss: 0.3948
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8085 - loss: 0.4045 - val_accuracy: 0.7750 - val_loss: 0.3840
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8537 - loss: 0.3235 - val_accuracy: 0.7750 - val_loss: 0.3965
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8219 - loss: 0.3739 - val_accuracy: 0.7750 - val_loss: 0.3881
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8128 - loss: 0.4217 - val_accuracy: 0.7750 - val_loss: 0.3922
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8117 - loss: 0.4194 - val_accuracy: 0.7750 - val_loss: 0.3749
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8306 - loss: 0.3600 - val_accuracy: 0.7750 - val_loss: 0.3982
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8285 - loss: 0.3690 - val_accuracy: 0.7750 - val_loss: 0.3807
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8443 - loss: 0.4031 - val_accuracy: 0.7750 - val_loss: 0.3874
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8140 - loss: 0.4120 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7793 - loss: 0.4085 - val_accuracy: 0.7750 - val_loss: 0.4009
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8266 - loss: 0.3745 - val_accuracy: 0.7750 - val_loss: 0.3910
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8652 - loss: 0.3347 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8514 - loss: 0.3320 - val_accuracy: 0.7750 - val_loss: 0.3785
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8110 - loss: 0.4221 - val_accuracy: 0.7750 - val_loss: 0.3972
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8214 - loss: 0.4127 - val_accuracy: 0.7750 - val_loss: 0.3975
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8019 - loss: 0.4263 - val_accuracy: 0.8000 - val_loss: 0.3737
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8157 - loss: 0.4464 - val_accuracy: 0.7750 - val_loss: 0.3951
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8418 - loss: 0.3552 - val_accuracy: 0.7750 - val_loss: 0.3996
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7841 - loss: 0.4341 - val_accuracy: 0.7750 - val_loss: 0.3801
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7874 - loss: 0.4388 - val_accuracy: 0.8000 - val_loss: 0.3600
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8561 - loss: 0.3704 - val_accuracy: 0.7750 - val_loss: 0.4064
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8109 - loss: 0.4108 - val_accuracy: 0.7750 - val_loss: 0.3786
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7954 - loss: 0.4340 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8275 - loss: 0.4118 - val_accuracy: 0.7750 - val_loss: 0.3955
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8418 - loss: 0.3735 - val_accuracy: 0.7750 - val_loss: 0.3972
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8526 - loss: 0.3343 - val_accuracy: 0.8000 - val_loss: 0.3742
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8371 - loss: 0.3890 - val_accuracy: 0.7750 - val_loss: 0.3798
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7673 - loss: 0.4510 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8370 - loss: 0.4215 - val_accuracy: 0.7750 - val_loss: 0.3933
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8248 - loss: 0.3808 - val_accuracy: 0.7750 - val_loss: 0.3972
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8011 - loss: 0.4225 - val_accuracy: 0.7750 - val_loss: 0.3820
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8153 - loss: 0.4004 - val_accuracy: 0.7750 - val_loss: 0.3797
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8444 - loss: 0.3595 - val_accuracy: 0.7750 - val_loss: 0.3795
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7997 - loss: 0.4123 - val_accuracy: 0.7750 - val_loss: 0.3865
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8163 - loss: 0.3717 - val_accuracy: 0.7750 - val_loss: 0.3892
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8436 - loss: 0.3697 - val_accuracy: 0.7750 - val_loss: 0.3678
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8236 - loss: 0.4016 - val_accuracy: 0.7750 - val_loss: 0.3937
# Epoch 59/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8188 - loss: 0.4444 - val_accuracy: 0.7750 - val_loss: 0.4057
# Epoch 60/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8287 - loss: 0.4178 - val_accuracy: 0.7750 - val_loss: 0.3939
# Epoch 61/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8388 - loss: 0.3634 - val_accuracy: 0.8000 - val_loss: 0.3718
# Epoch 62/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8476 - loss: 0.3445 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 63/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8303 - loss: 0.4022 - val_accuracy: 0.7750 - val_loss: 0.3968
# Epoch 64/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8149 - loss: 0.4136 - val_accuracy: 0.7750 - val_loss: 0.3875
# Epoch 65/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8501 - loss: 0.3825 - val_accuracy: 0.7750 - val_loss: 0.3817
# Epoch 66/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8631 - loss: 0.3393 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 67/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8523 - loss: 0.3354 - val_accuracy: 0.7750 - val_loss: 0.3756
# Epoch 68/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8383 - loss: 0.3948 - val_accuracy: 0.7750 - val_loss: 0.3983
# Epoch 69/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8279 - loss: 0.4423 - val_accuracy: 0.7750 - val_loss: 0.3970
# Epoch 70/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8454 - loss: 0.4029 - val_accuracy: 0.7750 - val_loss: 0.3868
# Epoch 71/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7920 - loss: 0.4540 - val_accuracy: 0.7750 - val_loss: 0.3984
# Epoch 72/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8273 - loss: 0.3744 - val_accuracy: 0.7750 - val_loss: 0.4146
# Epoch 73/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8444 - loss: 0.3531 - val_accuracy: 0.7750 - val_loss: 0.3826
# Epoch 74/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8089 - loss: 0.4079 - val_accuracy: 0.7750 - val_loss: 0.3739
# Epoch 75/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8245 - loss: 0.3797 - val_accuracy: 0.7750 - val_loss: 0.3928
# Epoch 76/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8609 - loss: 0.3362 - val_accuracy: 0.7750 - val_loss: 0.3898
# Epoch 77/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8426 - loss: 0.3534 - val_accuracy: 0.7750 - val_loss: 0.3776
# Epoch 78/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8225 - loss: 0.3691 - val_accuracy: 0.7750 - val_loss: 0.3910
# Epoch 79/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8487 - loss: 0.3710 - val_accuracy: 0.7750 - val_loss: 0.3992
# Epoch 80/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8106 - loss: 0.3989 - val_accuracy: 0.7750 - val_loss: 0.3726
# Epoch 81/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7924 - loss: 0.4259 - val_accuracy: 0.7750 - val_loss: 0.3737
# Epoch 82/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8449 - loss: 0.3705 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 83/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8175 - loss: 0.3904 - val_accuracy: 0.7750 - val_loss: 0.3920
# Epoch 84/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8371 - loss: 0.3880 - val_accuracy: 0.7750 - val_loss: 0.3806
# Epoch 85/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8136 - loss: 0.3854 - val_accuracy: 0.7750 - val_loss: 0.3821
# Epoch 86/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8332 - loss: 0.4105 - val_accuracy: 0.7750 - val_loss: 0.3887
# Epoch 87/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8288 - loss: 0.3793 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 88/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8246 - loss: 0.3716 - val_accuracy: 0.7750 - val_loss: 0.3826
# Epoch 89/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8471 - loss: 0.3556 - val_accuracy: 0.7750 - val_loss: 0.3897
# Epoch 90/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8463 - loss: 0.3501 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 91/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8280 - loss: 0.3593 - val_accuracy: 0.7750 - val_loss: 0.3867
# Epoch 92/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8102 - loss: 0.4191 - val_accuracy: 0.7750 - val_loss: 0.3872
# Epoch 93/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8006 - loss: 0.3867 - val_accuracy: 0.7750 - val_loss: 0.3808
# Epoch 94/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8193 - loss: 0.3861 - val_accuracy: 0.7750 - val_loss: 0.3889
# Epoch 95/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8145 - loss: 0.3694 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 96/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8168 - loss: 0.3512 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 97/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8501 - loss: 0.3906 - val_accuracy: 0.7750 - val_loss: 0.3790
# Epoch 98/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8201 - loss: 0.4042 - val_accuracy: 0.7750 - val_loss: 0.3842
# Epoch 99/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8089 - loss: 0.3716 - val_accuracy: 0.7750 - val_loss: 0.3966
# Epoch 100/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8431 - loss: 0.3371 - val_accuracy: 0.7750 - val_loss: 0.4009
# Epoch 101/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8168 - loss: 0.3813 - val_accuracy: 0.7750 - val_loss: 0.3727
# Epoch 102/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8609 - loss: 0.3649 - val_accuracy: 0.7750 - val_loss: 0.3753
# Epoch 103/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8423 - loss: 0.3820 - val_accuracy: 0.7750 - val_loss: 0.3803
# Epoch 104/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8132 - loss: 0.3867 - val_accuracy: 0.7750 - val_loss: 0.4024
# Epoch 105/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8423 - loss: 0.3653 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 106/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8249 - loss: 0.3557 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 107/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7889 - loss: 0.4119 - val_accuracy: 0.7750 - val_loss: 0.3795
# Epoch 108/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.8089 - loss: 0.4010 - val_accuracy: 0.7750 - val_loss: 0.3839
# Epoch 109/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8145 - loss: 0.4010 - val_accuracy: 0.7750 - val_loss: 0.3908
# Epoch 110/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8001 - loss: 0.4577 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 111/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8549 - loss: 0.3650 - val_accuracy: 0.7750 - val_loss: 0.3932
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8319 - loss: 0.3936 - val_accuracy: 0.7750 - val_loss: 0.3802
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7985 - loss: 0.4069 - val_accuracy: 0.7750 - val_loss: 0.3808
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8228 - loss: 0.3951 - val_accuracy: 0.7750 - val_loss: 0.3839
# Epoch 115/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8154 - loss: 0.3879 - val_accuracy: 0.7750 - val_loss: 0.3930
# Epoch 116/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8552 - loss: 0.3688 - val_accuracy: 0.7750 - val_loss: 0.3983
# Epoch 117/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8388 - loss: 0.3563 - val_accuracy: 0.7750 - val_loss: 0.3848
# Epoch 118/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8214 - loss: 0.4276 - val_accuracy: 0.7750 - val_loss: 0.3687
# Epoch 119/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8579 - loss: 0.3659 - val_accuracy: 0.7750 - val_loss: 0.3803
# Epoch 120/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8514 - loss: 0.3401 - val_accuracy: 0.7750 - val_loss: 0.3903
# Epoch 121/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7876 - loss: 0.4332 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 122/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8227 - loss: 0.3904 - val_accuracy: 0.7750 - val_loss: 0.3914
# Epoch 123/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8145 - loss: 0.4445 - val_accuracy: 0.7750 - val_loss: 0.3923
# Epoch 124/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8326 - loss: 0.3893 - val_accuracy: 0.7750 - val_loss: 0.3956
# Epoch 125/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8024 - loss: 0.3524 - val_accuracy: 0.7750 - val_loss: 0.3993
# Epoch 126/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8167 - loss: 0.3786 - val_accuracy: 0.7750 - val_loss: 0.3738
# Epoch 127/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8328 - loss: 0.3671 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 128/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8515 - loss: 0.3439 - val_accuracy: 0.7750 - val_loss: 0.3990
# Epoch 129/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8336 - loss: 0.3629 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 130/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7854 - loss: 0.4759 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 131/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8275 - loss: 0.3715 - val_accuracy: 0.7750 - val_loss: 0.3931
# Epoch 132/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8180 - loss: 0.4118 - val_accuracy: 0.7750 - val_loss: 0.3850
# Epoch 133/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8123 - loss: 0.4430 - val_accuracy: 0.7750 - val_loss: 0.3793
# Epoch 134/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8388 - loss: 0.3602 - val_accuracy: 0.7750 - val_loss: 0.3892
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8536 - loss: 0.3678 - val_accuracy: 0.7750 - val_loss: 0.3759
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8328 - loss: 0.3669 - val_accuracy: 0.7750 - val_loss: 0.3834
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8197 - loss: 0.3655 - val_accuracy: 0.7750 - val_loss: 0.3945
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8569 - loss: 0.3410 - val_accuracy: 0.7750 - val_loss: 0.3926
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8215 - loss: 0.4023 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7928 - loss: 0.4302 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8033 - loss: 0.4081 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8266 - loss: 0.3819 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7906 - loss: 0.4125 - val_accuracy: 0.7750 - val_loss: 0.4000
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8397 - loss: 0.3886 - val_accuracy: 0.7750 - val_loss: 0.3758
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8324 - loss: 0.3746 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8163 - loss: 0.4004 - val_accuracy: 0.7750 - val_loss: 0.3802
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8202 - loss: 0.3729 - val_accuracy: 0.7750 - val_loss: 0.3850
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8155 - loss: 0.4121 - val_accuracy: 0.7750 - val_loss: 0.3998
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8509 - loss: 0.3729 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8236 - loss: 0.3776 - val_accuracy: 0.7750 - val_loss: 0.3797
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8227 - loss: 0.4115 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8496 - loss: 0.3732 - val_accuracy: 0.7750 - val_loss: 0.3875
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8176 - loss: 0.4063 - val_accuracy: 0.7750 - val_loss: 0.3878
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8405 - loss: 0.3763 - val_accuracy: 0.7750 - val_loss: 0.3860
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8184 - loss: 0.4110 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8033 - loss: 0.3925 - val_accuracy: 0.7750 - val_loss: 0.3863
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8120 - loss: 0.3919 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8492 - loss: 0.3374 - val_accuracy: 0.7750 - val_loss: 0.3952
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8141 - loss: 0.4042 - val_accuracy: 0.7750 - val_loss: 0.3834
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8233 - loss: 0.3861 - val_accuracy: 0.7750 - val_loss: 0.3791
# Epoch 161/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8240 - loss: 0.3756 - val_accuracy: 0.7750 - val_loss: 0.3869
# Epoch 162/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8146 - loss: 0.3768 - val_accuracy: 0.7750 - val_loss: 0.3925
# Epoch 163/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8054 - loss: 0.4327 - val_accuracy: 0.7750 - val_loss: 0.3826
# Epoch 164/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8479 - loss: 0.3791 - val_accuracy: 0.7750 - val_loss: 0.3847
# Epoch 165/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8301 - loss: 0.3503 - val_accuracy: 0.7750 - val_loss: 0.3939
# Epoch 166/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8328 - loss: 0.3690 - val_accuracy: 0.7750 - val_loss: 0.3762
# Epoch 167/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7786 - loss: 0.4640 - val_accuracy: 0.7750 - val_loss: 0.3728
# Epoch 168/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8167 - loss: 0.4406 - val_accuracy: 0.7750 - val_loss: 0.3837
# Epoch 169/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8285 - loss: 0.3853 - val_accuracy: 0.7750 - val_loss: 0.3994
# Epoch 170/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8111 - loss: 0.4142 - val_accuracy: 0.7750 - val_loss: 0.3889
# Epoch 171/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8323 - loss: 0.3906 - val_accuracy: 0.7750 - val_loss: 0.3840
# Epoch 172/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8158 - loss: 0.3650 - val_accuracy: 0.7750 - val_loss: 0.3818
# Epoch 173/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8253 - loss: 0.4114 - val_accuracy: 0.7750 - val_loss: 0.3867
# Epoch 174/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8136 - loss: 0.4025 - val_accuracy: 0.7750 - val_loss: 0.3900
# Epoch 175/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8016 - loss: 0.4105 - val_accuracy: 0.7750 - val_loss: 0.3840
# Epoch 176/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8453 - loss: 0.3516 - val_accuracy: 0.7750 - val_loss: 0.3935
# Epoch 177/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8427 - loss: 0.3755 - val_accuracy: 0.7750 - val_loss: 0.3809
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8163 - loss: 0.3875 - val_accuracy: 0.7750 - val_loss: 0.3814
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8171 - loss: 0.4100 - val_accuracy: 0.7750 - val_loss: 0.3885
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7872 - loss: 0.4568 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8457 - loss: 0.3703 - val_accuracy: 0.7750 - val_loss: 0.3972
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7898 - loss: 0.4555 - val_accuracy: 0.7750 - val_loss: 0.3697
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8431 - loss: 0.3533 - val_accuracy: 0.7750 - val_loss: 0.3752
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7699 - loss: 0.4497 - val_accuracy: 0.7750 - val_loss: 0.3837
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8063 - loss: 0.4195 - val_accuracy: 0.7750 - val_loss: 0.3974
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8262 - loss: 0.3839 - val_accuracy: 0.7750 - val_loss: 0.3974
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8517 - loss: 0.3405 - val_accuracy: 0.7750 - val_loss: 0.3997
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8159 - loss: 0.4028 - val_accuracy: 0.8000 - val_loss: 0.3711
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8488 - loss: 0.3677 - val_accuracy: 0.8000 - val_loss: 0.3695
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8162 - loss: 0.3905 - val_accuracy: 0.7750 - val_loss: 0.3843
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8311 - loss: 0.3550 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8453 - loss: 0.3215 - val_accuracy: 0.7750 - val_loss: 0.3948
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8119 - loss: 0.4158 - val_accuracy: 0.7750 - val_loss: 0.3816
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8283 - loss: 0.3845 - val_accuracy: 0.7750 - val_loss: 0.3770
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8413 - loss: 0.3573 - val_accuracy: 0.7750 - val_loss: 0.3923
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8305 - loss: 0.3834 - val_accuracy: 0.7750 - val_loss: 0.3898
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8479 - loss: 0.3564 - val_accuracy: 0.7750 - val_loss: 0.3832
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8038 - loss: 0.3911 - val_accuracy: 0.7750 - val_loss: 0.3740
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8478 - loss: 0.3721 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7977 - loss: 0.4466 - val_accuracy: 0.7750 - val_loss: 0.3881
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8405 - loss: 0.3905 - val_accuracy: 0.7750 - val_loss: 0.3944
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8399 - loss: 0.3823 - val_accuracy: 0.7750 - val_loss: 0.3940
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8384 - loss: 0.3564 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8236 - loss: 0.3923 - val_accuracy: 0.7750 - val_loss: 0.3752
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8279 - loss: 0.3817 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8340 - loss: 0.4009 - val_accuracy: 0.7750 - val_loss: 0.3845
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8175 - loss: 0.4100 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8340 - loss: 0.3483 - val_accuracy: 0.7750 - val_loss: 0.3927
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8097 - loss: 0.4257 - val_accuracy: 0.7750 - val_loss: 0.3803
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8345 - loss: 0.3917 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8119 - loss: 0.4244 - val_accuracy: 0.7750 - val_loss: 0.3894
# Epoch 212/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8223 - loss: 0.3954 - val_accuracy: 0.7750 - val_loss: 0.3833
# Epoch 213/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8484 - loss: 0.3557 - val_accuracy: 0.7750 - val_loss: 0.3851
# Epoch 214/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8093 - loss: 0.3842 - val_accuracy: 0.7750 - val_loss: 0.3774
# Epoch 215/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8296 - loss: 0.3989 - val_accuracy: 0.7750 - val_loss: 0.3760
# Epoch 216/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8250 - loss: 0.3886 - val_accuracy: 0.7750 - val_loss: 0.3846
# Epoch 217/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8254 - loss: 0.3689 - val_accuracy: 0.7750 - val_loss: 0.4030
# Epoch 218/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8198 - loss: 0.3765 - val_accuracy: 0.7750 - val_loss: 0.3845
# Epoch 219/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8284 - loss: 0.3878 - val_accuracy: 0.7750 - val_loss: 0.3838
# Epoch 220/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7945 - loss: 0.3921 - val_accuracy: 0.7750 - val_loss: 0.3824
# Epoch 221/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8262 - loss: 0.3690 - val_accuracy: 0.7750 - val_loss: 0.3849
# Epoch 222/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8353 - loss: 0.3812 - val_accuracy: 0.7750 - val_loss: 0.3829
# Epoch 223/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8098 - loss: 0.4223 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 224/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7881 - loss: 0.4443 - val_accuracy: 0.7750 - val_loss: 0.3848
# Epoch 225/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7863 - loss: 0.4178 - val_accuracy: 0.7750 - val_loss: 0.3869
# Epoch 226/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8172 - loss: 0.3738 - val_accuracy: 0.7750 - val_loss: 0.3908
# Epoch 227/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8049 - loss: 0.3919 - val_accuracy: 0.7750 - val_loss: 0.3760
# Epoch 228/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8479 - loss: 0.3496 - val_accuracy: 0.7750 - val_loss: 0.3900
# Epoch 229/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7945 - loss: 0.4171 - val_accuracy: 0.7750 - val_loss: 0.3933
# Epoch 230/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8148 - loss: 0.4206 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 231/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8571 - loss: 0.3448 - val_accuracy: 0.7750 - val_loss: 0.3882
# Epoch 232/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8150 - loss: 0.4232 - val_accuracy: 0.7750 - val_loss: 0.3765
# Epoch 233/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8345 - loss: 0.3762 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 234/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8349 - loss: 0.3775 - val_accuracy: 0.7750 - val_loss: 0.3931
# Epoch 235/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7993 - loss: 0.4339 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 236/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7889 - loss: 0.4349 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 237/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8076 - loss: 0.4011 - val_accuracy: 0.7750 - val_loss: 0.3858
# Epoch 238/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7885 - loss: 0.4507 - val_accuracy: 0.7750 - val_loss: 0.3872
# Epoch 239/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8115 - loss: 0.3869 - val_accuracy: 0.7750 - val_loss: 0.3922
# Epoch 240/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8293 - loss: 0.3639 - val_accuracy: 0.7750 - val_loss: 0.3872
# Epoch 241/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8449 - loss: 0.3606 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 242/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8436 - loss: 0.3552 - val_accuracy: 0.7750 - val_loss: 0.3774
# Epoch 243/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7984 - loss: 0.4108 - val_accuracy: 0.7750 - val_loss: 0.3852
# Epoch 244/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8098 - loss: 0.3757 - val_accuracy: 0.7750 - val_loss: 0.3871
# Epoch 245/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8314 - loss: 0.3662 - val_accuracy: 0.7750 - val_loss: 0.3928
# Epoch 246/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8128 - loss: 0.4119 - val_accuracy: 0.7750 - val_loss: 0.3811
# Epoch 247/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8132 - loss: 0.3965 - val_accuracy: 0.7750 - val_loss: 0.3793
# Epoch 248/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8055 - loss: 0.4117 - val_accuracy: 0.7750 - val_loss: 0.3872
# Epoch 249/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8375 - loss: 0.3774 - val_accuracy: 0.7750 - val_loss: 0.3928
# Epoch 250/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7981 - loss: 0.4174 - val_accuracy: 0.7750 - val_loss: 0.3781
# Epoch 251/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8167 - loss: 0.3735 - val_accuracy: 0.7750 - val_loss: 0.3796
# Epoch 252/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8302 - loss: 0.4003 - val_accuracy: 0.7750 - val_loss: 0.3863
# Epoch 253/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7824 - loss: 0.4804 - val_accuracy: 0.7750 - val_loss: 0.3775
# Epoch 254/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8137 - loss: 0.3755 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 255/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8132 - loss: 0.4269 - val_accuracy: 0.7750 - val_loss: 0.3957
# Epoch 256/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8566 - loss: 0.3586 - val_accuracy: 0.7750 - val_loss: 0.3966
# Epoch 257/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8245 - loss: 0.3822 - val_accuracy: 0.7750 - val_loss: 0.3770
# Epoch 258/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8250 - loss: 0.4040 - val_accuracy: 0.7750 - val_loss: 0.3770
# Epoch 259/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8418 - loss: 0.3592 - val_accuracy: 0.7750 - val_loss: 0.3848
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7877 - loss: 0.4368 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8158 - loss: 0.4106 - val_accuracy: 0.7750 - val_loss: 0.3914
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7776 - loss: 0.4115 - val_accuracy: 0.7750 - val_loss: 0.3983
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8236 - loss: 0.3853 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7746 - loss: 0.4487 - val_accuracy: 0.7750 - val_loss: 0.3757
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8319 - loss: 0.3774 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8414 - loss: 0.3740 - val_accuracy: 0.7750 - val_loss: 0.3851
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8123 - loss: 0.4172 - val_accuracy: 0.7750 - val_loss: 0.3879
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8388 - loss: 0.3742 - val_accuracy: 0.7750 - val_loss: 0.3926
# Epoch 269/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8405 - loss: 0.3510 - val_accuracy: 0.7750 - val_loss: 0.3916
# Epoch 270/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8540 - loss: 0.3419 - val_accuracy: 0.7750 - val_loss: 0.3830
# Epoch 271/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8319 - loss: 0.4104 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 272/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8016 - loss: 0.3930 - val_accuracy: 0.7750 - val_loss: 0.3832
# Epoch 273/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8137 - loss: 0.4137 - val_accuracy: 0.7750 - val_loss: 0.3845
# Epoch 274/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8124 - loss: 0.3575 - val_accuracy: 0.7750 - val_loss: 0.3928
# Epoch 275/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8437 - loss: 0.3803 - val_accuracy: 0.7750 - val_loss: 0.3821
# Epoch 276/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7825 - loss: 0.4236 - val_accuracy: 0.7750 - val_loss: 0.3806
# Epoch 277/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8141 - loss: 0.4334 - val_accuracy: 0.7750 - val_loss: 0.3836
# Epoch 278/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8124 - loss: 0.3851 - val_accuracy: 0.7750 - val_loss: 0.4023
# Epoch 279/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8526 - loss: 0.3696 - val_accuracy: 0.7750 - val_loss: 0.3900
# Epoch 280/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.7806 - loss: 0.4471 - val_accuracy: 0.7750 - val_loss: 0.3799
# Epoch 281/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7993 - loss: 0.4073 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 282/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8153 - loss: 0.4054 - val_accuracy: 0.7750 - val_loss: 0.3967
# Epoch 283/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8475 - loss: 0.4024 - val_accuracy: 0.7750 - val_loss: 0.3818
# Epoch 284/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8028 - loss: 0.4311 - val_accuracy: 0.7750 - val_loss: 0.3852
# Epoch 285/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8206 - loss: 0.3837 - val_accuracy: 0.7750 - val_loss: 0.3894
# Epoch 286/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8206 - loss: 0.3930 - val_accuracy: 0.7750 - val_loss: 0.3857
# Epoch 287/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8301 - loss: 0.4092 - val_accuracy: 0.7750 - val_loss: 0.3874
# Epoch 288/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8258 - loss: 0.4018 - val_accuracy: 0.7750 - val_loss: 0.3858
# Epoch 289/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8136 - loss: 0.3828 - val_accuracy: 0.7750 - val_loss: 0.3819
# Epoch 290/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8054 - loss: 0.4352 - val_accuracy: 0.7750 - val_loss: 0.3769
# Epoch 291/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7955 - loss: 0.4513 - val_accuracy: 0.7750 - val_loss: 0.3803
# Epoch 292/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8106 - loss: 0.3877 - val_accuracy: 0.7750 - val_loss: 0.3917
# Epoch 293/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7937 - loss: 0.4113 - val_accuracy: 0.7750 - val_loss: 0.3981
# Epoch 294/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7746 - loss: 0.4414 - val_accuracy: 0.7750 - val_loss: 0.3816
# Epoch 295/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8384 - loss: 0.3694 - val_accuracy: 0.7750 - val_loss: 0.3874
# Epoch 296/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8727 - loss: 0.3469 - val_accuracy: 0.7750 - val_loss: 0.3909
# Epoch 297/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8177 - loss: 0.3630 - val_accuracy: 0.7750 - val_loss: 0.3786
# Epoch 298/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8102 - loss: 0.4254 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 299/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7972 - loss: 0.4063 - val_accuracy: 0.7750 - val_loss: 0.3853
# Epoch 300/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8518 - loss: 0.3577 - val_accuracy: 0.7750 - val_loss: 0.3891
# Epoch 301/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.8283 - loss: 0.4165 - val_accuracy: 0.7750 - val_loss: 0.3821
# Epoch 302/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7760 - loss: 0.4670 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 303/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8722 - loss: 0.3599 - val_accuracy: 0.7750 - val_loss: 0.3906
# Epoch 304/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8049 - loss: 0.3843 - val_accuracy: 0.7750 - val_loss: 0.3924
# Epoch 305/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8253 - loss: 0.3983 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 306/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7893 - loss: 0.4539 - val_accuracy: 0.7750 - val_loss: 0.3768
# Epoch 307/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8181 - loss: 0.3870 - val_accuracy: 0.7750 - val_loss: 0.3866
# Epoch 308/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7993 - loss: 0.3833 - val_accuracy: 0.7750 - val_loss: 0.3909
# Epoch 309/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8266 - loss: 0.4127 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 310/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8285 - loss: 0.3872 - val_accuracy: 0.7750 - val_loss: 0.3865
# Epoch 311/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8376 - loss: 0.3456 - val_accuracy: 0.7750 - val_loss: 0.3909
# Epoch 312/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8449 - loss: 0.3556 - val_accuracy: 0.7750 - val_loss: 0.3865
# Epoch 313/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8089 - loss: 0.4345 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 314/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8123 - loss: 0.3976 - val_accuracy: 0.7750 - val_loss: 0.3984
# Epoch 315/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8063 - loss: 0.3943 - val_accuracy: 0.7750 - val_loss: 0.3828
# Epoch 316/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8293 - loss: 0.3905 - val_accuracy: 0.7750 - val_loss: 0.3867
# Epoch 317/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8171 - loss: 0.3723 - val_accuracy: 0.7750 - val_loss: 0.3918
# Epoch 318/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8358 - loss: 0.4093 - val_accuracy: 0.7750 - val_loss: 0.3842
# Epoch 319/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8171 - loss: 0.4143 - val_accuracy: 0.7750 - val_loss: 0.3836
# Epoch 320/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8007 - loss: 0.4030 - val_accuracy: 0.7750 - val_loss: 0.3868
# Epoch 321/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8402 - loss: 0.3926 - val_accuracy: 0.7750 - val_loss: 0.3833
# Epoch 322/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8263 - loss: 0.3648 - val_accuracy: 0.7750 - val_loss: 0.3871
# Epoch 323/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8037 - loss: 0.4444 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 324/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8449 - loss: 0.3772 - val_accuracy: 0.7750 - val_loss: 0.3881
# Epoch 325/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8259 - loss: 0.4278 - val_accuracy: 0.7750 - val_loss: 0.3825
# Epoch 326/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8410 - loss: 0.3681 - val_accuracy: 0.7750 - val_loss: 0.3869
# Epoch 327/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.7742 - loss: 0.4657 - val_accuracy: 0.7750 - val_loss: 0.3785
# Epoch 328/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8228 - loss: 0.3671 - val_accuracy: 0.7750 - val_loss: 0.3951
# Epoch 329/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8159 - loss: 0.4264 - val_accuracy: 0.7750 - val_loss: 0.3792
# Epoch 330/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8162 - loss: 0.3998 - val_accuracy: 0.7750 - val_loss: 0.3764
# Epoch 331/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8157 - loss: 0.4066 - val_accuracy: 0.7750 - val_loss: 0.3945
# Epoch 332/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8155 - loss: 0.3896 - val_accuracy: 0.7750 - val_loss: 0.3840
# Epoch 333/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8150 - loss: 0.3661 - val_accuracy: 0.7750 - val_loss: 0.3793
# Epoch 334/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8102 - loss: 0.4177 - val_accuracy: 0.7750 - val_loss: 0.3830
# Epoch 335/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7841 - loss: 0.4047 - val_accuracy: 0.7750 - val_loss: 0.3885
# Epoch 336/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8240 - loss: 0.3975 - val_accuracy: 0.7750 - val_loss: 0.3864
# Epoch 337/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8410 - loss: 0.3904 - val_accuracy: 0.7750 - val_loss: 0.3875
# Epoch 338/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8449 - loss: 0.3814 - val_accuracy: 0.7750 - val_loss: 0.3846
# Epoch 339/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8098 - loss: 0.4013 - val_accuracy: 0.7750 - val_loss: 0.3758
# Epoch 340/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8518 - loss: 0.3456 - val_accuracy: 0.7750 - val_loss: 0.3852
# Epoch 341/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8805 - loss: 0.3363 - val_accuracy: 0.7750 - val_loss: 0.3849
# Epoch 342/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8453 - loss: 0.3702 - val_accuracy: 0.7750 - val_loss: 0.3853
# Epoch 343/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8345 - loss: 0.3450 - val_accuracy: 0.7750 - val_loss: 0.3847
# Epoch 344/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8319 - loss: 0.3695 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 345/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8414 - loss: 0.3577 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 346/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8162 - loss: 0.3832 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 347/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8036 - loss: 0.4431 - val_accuracy: 0.7750 - val_loss: 0.3915
# Epoch 348/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8389 - loss: 0.3699 - val_accuracy: 0.7750 - val_loss: 0.3903
# Epoch 349/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8336 - loss: 0.3883 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 350/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8193 - loss: 0.4149 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 351/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8236 - loss: 0.3839 - val_accuracy: 0.7750 - val_loss: 0.3871
# Epoch 352/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8640 - loss: 0.3457 - val_accuracy: 0.7750 - val_loss: 0.3887
# Epoch 353/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8310 - loss: 0.3881 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 354/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8158 - loss: 0.3786 - val_accuracy: 0.7750 - val_loss: 0.3777
# Epoch 355/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8253 - loss: 0.3761 - val_accuracy: 0.7750 - val_loss: 0.3880
# Epoch 356/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.7967 - loss: 0.4359 - val_accuracy: 0.7750 - val_loss: 0.3868
# Epoch 357/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8201 - loss: 0.3903 - val_accuracy: 0.7750 - val_loss: 0.3893
# Epoch 358/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8436 - loss: 0.3452 - val_accuracy: 0.7750 - val_loss: 0.3908
# Epoch 359/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8153 - loss: 0.4327 - val_accuracy: 0.8000 - val_loss: 0.3712
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8289 - loss: 0.3674 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8253 - loss: 0.3723 - val_accuracy: 0.7750 - val_loss: 0.3866
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8215 - loss: 0.3983 - val_accuracy: 0.7750 - val_loss: 0.3823
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8141 - loss: 0.4048 - val_accuracy: 0.7750 - val_loss: 0.3848
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8102 - loss: 0.3662 - val_accuracy: 0.7750 - val_loss: 0.3944
# Epoch 365/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8284 - loss: 0.3599 - val_accuracy: 0.7750 - val_loss: 0.3888
# Epoch 366/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8032 - loss: 0.3842 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 367/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8197 - loss: 0.4027 - val_accuracy: 0.7750 - val_loss: 0.3827
# Epoch 368/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8670 - loss: 0.3196 - val_accuracy: 0.7750 - val_loss: 0.3898
# Epoch 369/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.7937 - loss: 0.4509 - val_accuracy: 0.7750 - val_loss: 0.3795
# Epoch 370/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8497 - loss: 0.3663 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 371/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8193 - loss: 0.3785 - val_accuracy: 0.7750 - val_loss: 0.3802
# Epoch 372/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8214 - loss: 0.3991 - val_accuracy: 0.7750 - val_loss: 0.3867
# Epoch 373/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8766 - loss: 0.3309 - val_accuracy: 0.7750 - val_loss: 0.3924
# Epoch 374/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8371 - loss: 0.3646 - val_accuracy: 0.7750 - val_loss: 0.3938
# Epoch 375/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8032 - loss: 0.4308 - val_accuracy: 0.7750 - val_loss: 0.3815
# Epoch 376/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.7968 - loss: 0.4083 - val_accuracy: 0.7750 - val_loss: 0.3798
# Epoch 377/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8300 - loss: 0.4024 - val_accuracy: 0.7750 - val_loss: 0.3792
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8142 - loss: 0.4064 - val_accuracy: 0.7750 - val_loss: 0.3887
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8154 - loss: 0.3833 - val_accuracy: 0.7750 - val_loss: 0.3870
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8089 - loss: 0.4385 - val_accuracy: 0.7750 - val_loss: 0.3833
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8071 - loss: 0.3888 - val_accuracy: 0.7750 - val_loss: 0.3951
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8167 - loss: 0.4412 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8397 - loss: 0.3753 - val_accuracy: 0.7750 - val_loss: 0.3885
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8254 - loss: 0.3486 - val_accuracy: 0.7750 - val_loss: 0.3892
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8102 - loss: 0.3714 - val_accuracy: 0.7750 - val_loss: 0.3834
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8328 - loss: 0.3828 - val_accuracy: 0.7750 - val_loss: 0.3820
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8172 - loss: 0.3963 - val_accuracy: 0.7750 - val_loss: 0.3842
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8401 - loss: 0.3885 - val_accuracy: 0.7750 - val_loss: 0.3810
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8059 - loss: 0.3911 - val_accuracy: 0.7750 - val_loss: 0.3786
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8196 - loss: 0.4281 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8258 - loss: 0.3713 - val_accuracy: 0.7750 - val_loss: 0.3909
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8387 - loss: 0.3821 - val_accuracy: 0.7750 - val_loss: 0.3929
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8427 - loss: 0.3404 - val_accuracy: 0.7750 - val_loss: 0.3927
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8444 - loss: 0.3626 - val_accuracy: 0.7750 - val_loss: 0.3785
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8266 - loss: 0.3533 - val_accuracy: 0.7750 - val_loss: 0.3778
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8314 - loss: 0.3877 - val_accuracy: 0.7750 - val_loss: 0.3781
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8118 - loss: 0.4111 - val_accuracy: 0.7750 - val_loss: 0.3862
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8201 - loss: 0.4107 - val_accuracy: 0.7750 - val_loss: 0.3897
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8097 - loss: 0.4125 - val_accuracy: 0.7750 - val_loss: 0.3891
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8233 - loss: 0.4220 - val_accuracy: 0.7750 - val_loss: 0.3801
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8146 - loss: 0.3960 - val_accuracy: 0.7750 - val_loss: 0.3804
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8168 - loss: 0.4030 - val_accuracy: 0.7750 - val_loss: 0.3775
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8072 - loss: 0.3998 - val_accuracy: 0.7750 - val_loss: 0.3864
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8301 - loss: 0.3978 - val_accuracy: 0.7750 - val_loss: 0.3934
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8405 - loss: 0.3292 - val_accuracy: 0.7750 - val_loss: 0.3968
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8097 - loss: 0.3684 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8198 - loss: 0.4180 - val_accuracy: 0.7750 - val_loss: 0.3726
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8301 - loss: 0.3714 - val_accuracy: 0.7750 - val_loss: 0.3783
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8332 - loss: 0.3544 - val_accuracy: 0.7750 - val_loss: 0.3930
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8093 - loss: 0.4294 - val_accuracy: 0.7750 - val_loss: 0.3789
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8189 - loss: 0.4299 - val_accuracy: 0.7750 - val_loss: 0.3837
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8175 - loss: 0.3757 - val_accuracy: 0.7750 - val_loss: 0.3986
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8253 - loss: 0.3574 - val_accuracy: 0.7750 - val_loss: 0.3852
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.8128 - loss: 0.4245 - val_accuracy: 0.7750 - val_loss: 0.3754
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8479 - loss: 0.3731 - val_accuracy: 0.7750 - val_loss: 0.3924
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8275 - loss: 0.3662 - val_accuracy: 0.7750 - val_loss: 0.3703
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8250 - loss: 0.3573 - val_accuracy: 0.7750 - val_loss: 0.3761
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8591 - loss: 0.3655 - val_accuracy: 0.7750 - val_loss: 0.3876
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8262 - loss: 0.3858 - val_accuracy: 0.7750 - val_loss: 0.3890
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8059 - loss: 0.4346 - val_accuracy: 0.7750 - val_loss: 0.3766
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8228 - loss: 0.3789 - val_accuracy: 0.7750 - val_loss: 0.3880
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8198 - loss: 0.3992 - val_accuracy: 0.7750 - val_loss: 0.3877
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8428 - loss: 0.3334 - val_accuracy: 0.7750 - val_loss: 0.3891
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.7980 - loss: 0.4391 - val_accuracy: 0.7750 - val_loss: 0.3798
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8057 - loss: 0.4162 - val_accuracy: 0.7750 - val_loss: 0.3795
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8614 - loss: 0.3363 - val_accuracy: 0.7750 - val_loss: 0.4037
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8370 - loss: 0.3731 - val_accuracy: 0.7750 - val_loss: 0.3767
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8280 - loss: 0.3778 - val_accuracy: 0.7750 - val_loss: 0.4091
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8070 - loss: 0.4214 - val_accuracy: 0.7750 - val_loss: 0.3731
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8036 - loss: 0.4329 - val_accuracy: 0.7750 - val_loss: 0.3925
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8476 - loss: 0.3349 - val_accuracy: 0.7750 - val_loss: 0.3885
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8293 - loss: 0.4314 - val_accuracy: 0.7750 - val_loss: 0.3843
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.8363 - loss: 0.3746 - val_accuracy: 0.7750 - val_loss: 0.4325
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8159 - loss: 0.3846 - val_accuracy: 0.8000 - val_loss: 0.3738
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8635 - loss: 0.3741 - val_accuracy: 0.7750 - val_loss: 0.4358
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.8530 - loss: 0.3883 - val_accuracy: 0.7750 - val_loss: 0.3748
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8344 - loss: 0.3927 - val_accuracy: 0.8000 - val_loss: 0.3817
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8375 - loss: 0.3954 - val_accuracy: 0.7750 - val_loss: 0.3900
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8297 - loss: 0.4343 - val_accuracy: 0.8000 - val_loss: 0.3685
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8319 - loss: 0.4238 - val_accuracy: 0.7750 - val_loss: 0.3824
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8257 - loss: 0.3883 - val_accuracy: 0.7750 - val_loss: 0.3994
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8392 - loss: 0.3984 - val_accuracy: 0.7750 - val_loss: 0.3688
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8259 - loss: 0.4050 - val_accuracy: 0.7750 - val_loss: 0.3729
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8480 - loss: 0.3645 - val_accuracy: 0.7750 - val_loss: 0.3915
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8163 - loss: 0.4042 - val_accuracy: 0.7750 - val_loss: 0.3830
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8401 - loss: 0.3620 - val_accuracy: 0.7750 - val_loss: 0.3872
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8205 - loss: 0.4010 - val_accuracy: 0.7750 - val_loss: 0.3896
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8496 - loss: 0.3916 - val_accuracy: 0.7750 - val_loss: 0.3799
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8183 - loss: 0.3929 - val_accuracy: 0.7750 - val_loss: 0.3782
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8166 - loss: 0.4676 - val_accuracy: 0.7750 - val_loss: 0.3850
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8361 - loss: 0.3649 - val_accuracy: 0.7750 - val_loss: 0.3893
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8115 - loss: 0.4112 - val_accuracy: 0.7750 - val_loss: 0.3788
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8254 - loss: 0.3664 - val_accuracy: 0.7750 - val_loss: 0.3822
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.8250 - loss: 0.3556 - val_accuracy: 0.7750 - val_loss: 0.3841
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8215 - loss: 0.3842 - val_accuracy: 0.7750 - val_loss: 0.3845
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8245 - loss: 0.4116 - val_accuracy: 0.7750 - val_loss: 0.3829
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8275 - loss: 0.4069 - val_accuracy: 0.7750 - val_loss: 0.3837
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8137 - loss: 0.3816 - val_accuracy: 0.7750 - val_loss: 0.3892
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8241 - loss: 0.3846 - val_accuracy: 0.7750 - val_loss: 0.3831
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8206 - loss: 0.4166 - val_accuracy: 0.7750 - val_loss: 0.3863
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8271 - loss: 0.3884 - val_accuracy: 0.7750 - val_loss: 0.3895
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8245 - loss: 0.3992 - val_accuracy: 0.7750 - val_loss: 0.3781
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8240 - loss: 0.4174 - val_accuracy: 0.7750 - val_loss: 0.3773
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8123 - loss: 0.4303 - val_accuracy: 0.7750 - val_loss: 0.3835
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8084 - loss: 0.4083 - val_accuracy: 0.7750 - val_loss: 0.3912
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8293 - loss: 0.4076 - val_accuracy: 0.7750 - val_loss: 0.3880
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.7957 - loss: 0.4312 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8353 - loss: 0.4044 - val_accuracy: 0.7750 - val_loss: 0.3875
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7993 - loss: 0.4186 - val_accuracy: 0.7750 - val_loss: 0.3848
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8232 - loss: 0.3954 - val_accuracy: 0.7750 - val_loss: 0.3863
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.8444 - loss: 0.3784 - val_accuracy: 0.7750 - val_loss: 0.3888
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8240 - loss: 0.3710 - val_accuracy: 0.7750 - val_loss: 0.3862
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8019 - loss: 0.4242 - val_accuracy: 0.7750 - val_loss: 0.3776
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8618 - loss: 0.3389 - val_accuracy: 0.7750 - val_loss: 0.3869
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8246 - loss: 0.3899 - val_accuracy: 0.7750 - val_loss: 0.3854
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8275 - loss: 0.4014 - val_accuracy: 0.7750 - val_loss: 0.3787
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8461 - loss: 0.3787 - val_accuracy: 0.7750 - val_loss: 0.3921
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7949 - loss: 0.4487 - val_accuracy: 0.7750 - val_loss: 0.3861
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.8397 - loss: 0.3588 - val_accuracy: 0.7750 - val_loss: 0.3894
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8359 - loss: 0.3689 - val_accuracy: 0.7750 - val_loss: 0.3844
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8358 - loss: 0.3836 - val_accuracy: 0.7750 - val_loss: 0.3774
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8262 - loss: 0.3475 - val_accuracy: 0.7750 - val_loss: 0.3800
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8457 - loss: 0.3593 - val_accuracy: 0.7750 - val_loss: 0.3798
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8272 - loss: 0.3811 - val_accuracy: 0.7750 - val_loss: 0.3820
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8405 - loss: 0.3771 - val_accuracy: 0.7750 - val_loss: 0.3923
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8010 - loss: 0.4010 - val_accuracy: 0.7750 - val_loss: 0.3871
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8232 - loss: 0.3806 - val_accuracy: 0.7750 - val_loss: 0.3919
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8327 - loss: 0.3890 - val_accuracy: 0.7750 - val_loss: 0.3846
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8119 - loss: 0.4198 - val_accuracy: 0.7750 - val_loss: 0.3792
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8298 - loss: 0.3504 - val_accuracy: 0.7750 - val_loss: 0.3849
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8227 - loss: 0.4042 - val_accuracy: 0.7750 - val_loss: 0.3774
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8591 - loss: 0.3765 - val_accuracy: 0.7750 - val_loss: 0.3866
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.7825 - loss: 0.4360 - val_accuracy: 0.7750 - val_loss: 0.3784
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8519 - loss: 0.3511 - val_accuracy: 0.7750 - val_loss: 0.3869
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8202 - loss: 0.3897 - val_accuracy: 0.7750 - val_loss: 0.3893
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.8271 - loss: 0.3574 - val_accuracy: 0.7750 - val_loss: 0.3883
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8531 - loss: 0.3736 - val_accuracy: 0.7750 - val_loss: 0.3850
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8214 - loss: 0.3859 - val_accuracy: 0.7750 - val_loss: 0.3824
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8220 - loss: 0.3857 - val_accuracy: 0.7750 - val_loss: 0.3801
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8288 - loss: 0.3570 - val_accuracy: 0.7750 - val_loss: 0.3880

# %%
# Plot the decision region
plot_decision_regions(X, y, clf=model, legend=2);
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 7s 735us/step

# %% [markdown]
# #### **Neural Network with Non-Linear Activation in the Hidden Layers**

# %%
# Build a neural network with non-linear activation used in the hidden layers
model = Sequential()

model.add(Dense(128, activation="relu", input_dim=2))
model.add(Dense(128, activation="relu", input_dim=2))
model.add(Dense(1, activation="sigmoid"))

model.compile(optimizer=Adam(learning_rate=0.01), loss="binary_crossentropy", metrics=["accuracy"])

history = model.fit(X, y, epochs=500, validation_split=0.2, verbose=1)
# Out:
# Epoch 1/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 60ms/step - accuracy: 0.7033 - loss: 0.5335 - val_accuracy: 0.8000 - val_loss: 0.4054
# Epoch 2/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8589 - loss: 0.3780 - val_accuracy: 0.7750 - val_loss: 0.3939
# Epoch 3/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8586 - loss: 0.3345 - val_accuracy: 0.7750 - val_loss: 0.3071
# Epoch 4/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8241 - loss: 0.3280 - val_accuracy: 0.7750 - val_loss: 0.3259
# Epoch 5/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.7939 - loss: 0.3803 - val_accuracy: 0.8000 - val_loss: 0.3526
# Epoch 6/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8620 - loss: 0.2848 - val_accuracy: 0.7750 - val_loss: 0.4293
# Epoch 7/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8672 - loss: 0.2723 - val_accuracy: 0.9000 - val_loss: 0.3340
# Epoch 8/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8247 - loss: 0.3058 - val_accuracy: 0.7750 - val_loss: 0.3401
# Epoch 9/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.7951 - loss: 0.3065 - val_accuracy: 0.7750 - val_loss: 0.4060
# Epoch 10/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8496 - loss: 0.2932 - val_accuracy: 0.8000 - val_loss: 0.4148
# Epoch 11/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8411 - loss: 0.3210 - val_accuracy: 0.8000 - val_loss: 0.3729
# Epoch 12/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8486 - loss: 0.2935 - val_accuracy: 0.9000 - val_loss: 0.3741
# Epoch 13/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8641 - loss: 0.2853 - val_accuracy: 0.8000 - val_loss: 0.4053
# Epoch 14/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8836 - loss: 0.2580 - val_accuracy: 0.8000 - val_loss: 0.4171
# Epoch 15/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8146 - loss: 0.3055 - val_accuracy: 0.8750 - val_loss: 0.3645
# Epoch 16/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8648 - loss: 0.2680 - val_accuracy: 0.8750 - val_loss: 0.3848
# Epoch 17/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8493 - loss: 0.2785 - val_accuracy: 0.7750 - val_loss: 0.4407
# Epoch 18/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8534 - loss: 0.2674 - val_accuracy: 0.8750 - val_loss: 0.3845
# Epoch 19/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8476 - loss: 0.2796 - val_accuracy: 0.8500 - val_loss: 0.3783
# Epoch 20/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8337 - loss: 0.2900 - val_accuracy: 0.8750 - val_loss: 0.4147
# Epoch 21/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8921 - loss: 0.2509 - val_accuracy: 0.8000 - val_loss: 0.4410
# Epoch 22/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9022 - loss: 0.2072 - val_accuracy: 0.8750 - val_loss: 0.3825
# Epoch 23/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8653 - loss: 0.2402 - val_accuracy: 0.8750 - val_loss: 0.3836
# Epoch 24/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8727 - loss: 0.2544 - val_accuracy: 0.7750 - val_loss: 0.4463
# Epoch 25/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8780 - loss: 0.2479 - val_accuracy: 0.8500 - val_loss: 0.4108
# Epoch 26/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8697 - loss: 0.2599 - val_accuracy: 0.8750 - val_loss: 0.3718
# Epoch 27/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8633 - loss: 0.2612 - val_accuracy: 0.8750 - val_loss: 0.3925
# Epoch 28/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8653 - loss: 0.2471 - val_accuracy: 0.8500 - val_loss: 0.4352
# Epoch 29/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8322 - loss: 0.2773 - val_accuracy: 0.8750 - val_loss: 0.3991
# Epoch 30/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9056 - loss: 0.2419 - val_accuracy: 0.8500 - val_loss: 0.4321
# Epoch 31/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8504 - loss: 0.2552 - val_accuracy: 0.8750 - val_loss: 0.4215
# Epoch 32/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8689 - loss: 0.2583 - val_accuracy: 0.8750 - val_loss: 0.4197
# Epoch 33/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8958 - loss: 0.2499 - val_accuracy: 0.8750 - val_loss: 0.4100
# Epoch 34/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9118 - loss: 0.2066 - val_accuracy: 0.8750 - val_loss: 0.4253
# Epoch 35/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8913 - loss: 0.2467 - val_accuracy: 0.8750 - val_loss: 0.3788
# Epoch 36/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8773 - loss: 0.2239 - val_accuracy: 0.8250 - val_loss: 0.4299
# Epoch 37/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8560 - loss: 0.2551 - val_accuracy: 0.8750 - val_loss: 0.3865
# Epoch 38/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8911 - loss: 0.2393 - val_accuracy: 0.8750 - val_loss: 0.4223
# Epoch 39/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8661 - loss: 0.2565 - val_accuracy: 0.8750 - val_loss: 0.3587
# Epoch 40/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8918 - loss: 0.2595 - val_accuracy: 0.9000 - val_loss: 0.4586
# Epoch 41/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8474 - loss: 0.2582 - val_accuracy: 0.8500 - val_loss: 0.4406
# Epoch 42/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8326 - loss: 0.2517 - val_accuracy: 0.8750 - val_loss: 0.4040
# Epoch 43/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8660 - loss: 0.2491 - val_accuracy: 0.9000 - val_loss: 0.4250
# Epoch 44/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8951 - loss: 0.2113 - val_accuracy: 0.8500 - val_loss: 0.4177
# Epoch 45/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.8464 - loss: 0.2475 - val_accuracy: 0.8750 - val_loss: 0.4188
# Epoch 46/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8609 - loss: 0.2072 - val_accuracy: 0.8750 - val_loss: 0.4449
# Epoch 47/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8832 - loss: 0.2252 - val_accuracy: 0.8750 - val_loss: 0.4136
# Epoch 48/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8926 - loss: 0.2075 - val_accuracy: 0.8750 - val_loss: 0.4333
# Epoch 49/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8949 - loss: 0.2089 - val_accuracy: 0.8750 - val_loss: 0.4243
# Epoch 50/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8753 - loss: 0.2049 - val_accuracy: 0.8750 - val_loss: 0.4593
# Epoch 51/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8793 - loss: 0.2182 - val_accuracy: 0.8750 - val_loss: 0.4311
# Epoch 52/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9195 - loss: 0.1960 - val_accuracy: 0.8500 - val_loss: 0.4341
# Epoch 53/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8832 - loss: 0.2161 - val_accuracy: 0.9000 - val_loss: 0.4288
# Epoch 54/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8862 - loss: 0.2221 - val_accuracy: 0.8750 - val_loss: 0.4617
# Epoch 55/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8576 - loss: 0.2399 - val_accuracy: 0.8750 - val_loss: 0.4583
# Epoch 56/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9163 - loss: 0.1968 - val_accuracy: 0.8750 - val_loss: 0.5052
# Epoch 57/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8944 - loss: 0.1997 - val_accuracy: 0.8750 - val_loss: 0.5106
# Epoch 58/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9004 - loss: 0.2054 - val_accuracy: 0.8750 - val_loss: 0.4101
# Epoch 59/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8801 - loss: 0.2000 - val_accuracy: 0.9000 - val_loss: 0.3867
# Epoch 60/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8774 - loss: 0.2139 - val_accuracy: 0.8750 - val_loss: 0.4410
# Epoch 61/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9115 - loss: 0.1867 - val_accuracy: 0.8750 - val_loss: 0.4971
# Epoch 62/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8879 - loss: 0.1958 - val_accuracy: 0.8750 - val_loss: 0.4395
# Epoch 63/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8660 - loss: 0.2049 - val_accuracy: 0.9000 - val_loss: 0.4351
# Epoch 64/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.8942 - loss: 0.2132 - val_accuracy: 0.8750 - val_loss: 0.4821
# Epoch 65/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8828 - loss: 0.1946 - val_accuracy: 0.8750 - val_loss: 0.5148
# Epoch 66/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9194 - loss: 0.1856 - val_accuracy: 0.8750 - val_loss: 0.4630
# Epoch 67/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8675 - loss: 0.2289 - val_accuracy: 0.8750 - val_loss: 0.4739
# Epoch 68/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8644 - loss: 0.2244 - val_accuracy: 0.8750 - val_loss: 0.6036
# Epoch 69/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8537 - loss: 0.2356 - val_accuracy: 0.8750 - val_loss: 0.4965
# Epoch 70/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8785 - loss: 0.2091 - val_accuracy: 0.8750 - val_loss: 0.5228
# Epoch 71/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8523 - loss: 0.2365 - val_accuracy: 0.8750 - val_loss: 0.6021
# Epoch 72/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8766 - loss: 0.2113 - val_accuracy: 0.9000 - val_loss: 0.4930
# Epoch 73/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8952 - loss: 0.1980 - val_accuracy: 0.8750 - val_loss: 0.4238
# Epoch 74/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - accuracy: 0.8835 - loss: 0.2197 - val_accuracy: 0.9000 - val_loss: 0.4833
# Epoch 75/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9024 - loss: 0.1787 - val_accuracy: 0.9000 - val_loss: 0.5250
# Epoch 76/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8957 - loss: 0.1815 - val_accuracy: 0.8750 - val_loss: 0.4169
# Epoch 77/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8697 - loss: 0.2268 - val_accuracy: 0.8750 - val_loss: 0.5302
# Epoch 78/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9054 - loss: 0.1684 - val_accuracy: 0.9000 - val_loss: 0.6026
# Epoch 79/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9102 - loss: 0.1939 - val_accuracy: 0.8750 - val_loss: 0.4556
# Epoch 80/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8988 - loss: 0.2005 - val_accuracy: 0.8500 - val_loss: 0.4956
# Epoch 81/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8504 - loss: 0.2299 - val_accuracy: 0.8750 - val_loss: 0.4726
# Epoch 82/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8427 - loss: 0.2186 - val_accuracy: 0.8750 - val_loss: 0.4830
# Epoch 83/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8441 - loss: 0.2502 - val_accuracy: 0.9000 - val_loss: 0.5379
# Epoch 84/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8624 - loss: 0.2132 - val_accuracy: 0.8750 - val_loss: 0.4724
# Epoch 85/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9200 - loss: 0.1685 - val_accuracy: 0.8750 - val_loss: 0.4497
# Epoch 86/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8727 - loss: 0.2130 - val_accuracy: 0.8750 - val_loss: 0.4726
# Epoch 87/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8714 - loss: 0.2067 - val_accuracy: 0.8750 - val_loss: 0.4911
# Epoch 88/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.8946 - loss: 0.1905 - val_accuracy: 0.8750 - val_loss: 0.4853
# Epoch 89/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9038 - loss: 0.1812 - val_accuracy: 0.8750 - val_loss: 0.5616
# Epoch 90/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9237 - loss: 0.1696 - val_accuracy: 0.9000 - val_loss: 0.5529
# Epoch 91/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9076 - loss: 0.2071 - val_accuracy: 0.9250 - val_loss: 0.5123
# Epoch 92/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 0.9212 - loss: 0.1607 - val_accuracy: 0.8750 - val_loss: 0.5981
# Epoch 93/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9034 - loss: 0.1790 - val_accuracy: 0.8750 - val_loss: 0.5563
# Epoch 94/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9194 - loss: 0.1623 - val_accuracy: 0.8750 - val_loss: 0.5694
# Epoch 95/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8863 - loss: 0.1770 - val_accuracy: 0.8750 - val_loss: 0.6176
# Epoch 96/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8842 - loss: 0.1791 - val_accuracy: 0.8750 - val_loss: 0.5475
# Epoch 97/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9122 - loss: 0.1694 - val_accuracy: 0.9000 - val_loss: 0.5417
# Epoch 98/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9190 - loss: 0.1534 - val_accuracy: 0.8750 - val_loss: 0.6261
# Epoch 99/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8370 - loss: 0.2460 - val_accuracy: 0.8750 - val_loss: 0.5270
# Epoch 100/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8528 - loss: 0.2233 - val_accuracy: 0.9000 - val_loss: 0.5566
# Epoch 101/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8925 - loss: 0.2204 - val_accuracy: 0.8750 - val_loss: 0.5468
# Epoch 102/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8998 - loss: 0.2294 - val_accuracy: 0.9000 - val_loss: 0.5625
# Epoch 103/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8207 - loss: 0.2738 - val_accuracy: 0.8750 - val_loss: 0.5837
# Epoch 104/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8595 - loss: 0.2124 - val_accuracy: 0.8750 - val_loss: 0.6026
# Epoch 105/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8417 - loss: 0.2480 - val_accuracy: 0.8750 - val_loss: 0.5954
# Epoch 106/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9009 - loss: 0.1918 - val_accuracy: 0.8750 - val_loss: 0.5809
# Epoch 107/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8711 - loss: 0.2329 - val_accuracy: 0.8750 - val_loss: 0.6146
# Epoch 108/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8924 - loss: 0.2024 - val_accuracy: 0.8750 - val_loss: 0.6014
# Epoch 109/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9208 - loss: 0.1915 - val_accuracy: 0.8750 - val_loss: 0.5156
# Epoch 110/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8989 - loss: 0.1920 - val_accuracy: 0.8750 - val_loss: 0.5617
# Epoch 111/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9058 - loss: 0.2035 - val_accuracy: 0.8750 - val_loss: 0.6282
# Epoch 112/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9179 - loss: 0.1701 - val_accuracy: 0.8750 - val_loss: 0.6403
# Epoch 113/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9214 - loss: 0.1783 - val_accuracy: 0.8750 - val_loss: 0.6347
# Epoch 114/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9297 - loss: 0.1556 - val_accuracy: 0.8750 - val_loss: 0.6095
# Epoch 115/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8544 - loss: 0.2064 - val_accuracy: 0.8750 - val_loss: 0.6229
# Epoch 116/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9149 - loss: 0.1687 - val_accuracy: 0.9000 - val_loss: 0.6544
# Epoch 117/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9189 - loss: 0.1691 - val_accuracy: 0.9000 - val_loss: 0.6740
# Epoch 118/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8843 - loss: 0.1907 - val_accuracy: 0.9000 - val_loss: 0.5965
# Epoch 119/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8929 - loss: 0.1789 - val_accuracy: 0.8750 - val_loss: 0.5961
# Epoch 120/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9349 - loss: 0.1311 - val_accuracy: 0.8750 - val_loss: 0.6400
# Epoch 121/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8857 - loss: 0.1834 - val_accuracy: 0.8750 - val_loss: 0.6782
# Epoch 122/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9058 - loss: 0.1685 - val_accuracy: 0.8750 - val_loss: 0.6493
# Epoch 123/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8930 - loss: 0.1794 - val_accuracy: 0.8750 - val_loss: 0.6819
# Epoch 124/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8779 - loss: 0.1901 - val_accuracy: 0.9000 - val_loss: 0.6787
# Epoch 125/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9058 - loss: 0.1592 - val_accuracy: 0.8750 - val_loss: 0.6849
# Epoch 126/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8938 - loss: 0.1829 - val_accuracy: 0.8750 - val_loss: 0.7337
# Epoch 127/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8792 - loss: 0.1952 - val_accuracy: 0.8750 - val_loss: 0.6039
# Epoch 128/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9237 - loss: 0.1563 - val_accuracy: 0.8750 - val_loss: 0.6033
# Epoch 129/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9129 - loss: 0.1613 - val_accuracy: 0.8750 - val_loss: 0.6679
# Epoch 130/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9008 - loss: 0.1953 - val_accuracy: 0.9000 - val_loss: 0.6591
# Epoch 131/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9055 - loss: 0.1785 - val_accuracy: 0.8750 - val_loss: 0.7087
# Epoch 132/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8863 - loss: 0.1989 - val_accuracy: 0.9000 - val_loss: 0.6444
# Epoch 133/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8644 - loss: 0.2334 - val_accuracy: 0.8750 - val_loss: 0.6483
# Epoch 134/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8806 - loss: 0.2251 - val_accuracy: 0.8750 - val_loss: 0.6542
# Epoch 135/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9170 - loss: 0.1884 - val_accuracy: 0.8750 - val_loss: 0.6329
# Epoch 136/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9048 - loss: 0.1827 - val_accuracy: 0.8500 - val_loss: 0.7028
# Epoch 137/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.8824 - loss: 0.2068 - val_accuracy: 0.8750 - val_loss: 0.6322
# Epoch 138/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8891 - loss: 0.1849 - val_accuracy: 0.8500 - val_loss: 0.6456
# Epoch 139/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8763 - loss: 0.1839 - val_accuracy: 0.8500 - val_loss: 0.6387
# Epoch 140/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - accuracy: 0.8879 - loss: 0.1802 - val_accuracy: 0.8750 - val_loss: 0.6407
# Epoch 141/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8898 - loss: 0.2074 - val_accuracy: 0.8750 - val_loss: 0.6138
# Epoch 142/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9266 - loss: 0.1695 - val_accuracy: 0.8750 - val_loss: 0.6540
# Epoch 143/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9007 - loss: 0.1875 - val_accuracy: 0.8500 - val_loss: 0.6993
# Epoch 144/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8886 - loss: 0.1764 - val_accuracy: 0.8500 - val_loss: 0.7015
# Epoch 145/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9122 - loss: 0.1620 - val_accuracy: 0.8750 - val_loss: 0.7265
# Epoch 146/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9201 - loss: 0.1707 - val_accuracy: 0.8750 - val_loss: 0.7268
# Epoch 147/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9167 - loss: 0.1325 - val_accuracy: 0.8500 - val_loss: 0.7305
# Epoch 148/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9219 - loss: 0.1442 - val_accuracy: 0.8750 - val_loss: 0.7579
# Epoch 149/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9275 - loss: 0.1382 - val_accuracy: 0.8750 - val_loss: 0.8124
# Epoch 150/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8825 - loss: 0.1741 - val_accuracy: 0.8750 - val_loss: 0.6895
# Epoch 151/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9016 - loss: 0.1722 - val_accuracy: 0.9000 - val_loss: 0.6976
# Epoch 152/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9503 - loss: 0.1283 - val_accuracy: 0.8750 - val_loss: 0.7983
# Epoch 153/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8939 - loss: 0.1726 - val_accuracy: 0.8750 - val_loss: 0.8025
# Epoch 154/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9345 - loss: 0.1648 - val_accuracy: 0.9000 - val_loss: 0.6855
# Epoch 155/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9080 - loss: 0.1640 - val_accuracy: 0.9000 - val_loss: 0.7172
# Epoch 156/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9120 - loss: 0.1608 - val_accuracy: 0.8750 - val_loss: 0.8305
# Epoch 157/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9201 - loss: 0.1591 - val_accuracy: 0.8750 - val_loss: 0.8321
# Epoch 158/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9322 - loss: 0.1331 - val_accuracy: 0.8750 - val_loss: 0.8504
# Epoch 159/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9239 - loss: 0.1507 - val_accuracy: 0.8750 - val_loss: 0.8875
# Epoch 160/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9084 - loss: 0.1455 - val_accuracy: 0.8750 - val_loss: 0.8729
# Epoch 161/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9162 - loss: 0.1447 - val_accuracy: 0.8750 - val_loss: 0.8710
# Epoch 162/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9352 - loss: 0.1362 - val_accuracy: 0.8750 - val_loss: 0.9179
# Epoch 163/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9311 - loss: 0.1378 - val_accuracy: 0.9000 - val_loss: 0.8979
# Epoch 164/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9110 - loss: 0.1630 - val_accuracy: 0.9000 - val_loss: 0.8832
# Epoch 165/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9370 - loss: 0.1275 - val_accuracy: 0.8750 - val_loss: 0.9637
# Epoch 166/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9473 - loss: 0.1365 - val_accuracy: 0.9000 - val_loss: 0.8766
# Epoch 167/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9135 - loss: 0.1556 - val_accuracy: 0.9250 - val_loss: 0.8327
# Epoch 168/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9411 - loss: 0.1473 - val_accuracy: 0.8750 - val_loss: 0.9767
# Epoch 169/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9328 - loss: 0.1392 - val_accuracy: 0.8750 - val_loss: 0.9874
# Epoch 170/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9330 - loss: 0.1416 - val_accuracy: 0.9000 - val_loss: 0.8750
# Epoch 171/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9178 - loss: 0.1528 - val_accuracy: 0.9250 - val_loss: 0.8944
# Epoch 172/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9274 - loss: 0.1429 - val_accuracy: 0.8750 - val_loss: 0.9587
# Epoch 173/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9085 - loss: 0.1634 - val_accuracy: 0.8750 - val_loss: 1.0066
# Epoch 174/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8992 - loss: 0.1769 - val_accuracy: 0.8500 - val_loss: 0.9130
# Epoch 175/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8674 - loss: 0.3654 - val_accuracy: 0.8500 - val_loss: 1.0056
# Epoch 176/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.8813 - loss: 0.3292 - val_accuracy: 0.8500 - val_loss: 0.9240
# Epoch 177/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8941 - loss: 0.2204 - val_accuracy: 0.8250 - val_loss: 0.8312
# Epoch 178/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8441 - loss: 0.3002 - val_accuracy: 0.8250 - val_loss: 0.7837
# Epoch 179/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8395 - loss: 0.4050 - val_accuracy: 0.8000 - val_loss: 0.7262
# Epoch 180/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.8726 - loss: 0.2214 - val_accuracy: 0.9000 - val_loss: 0.7270
# Epoch 181/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9154 - loss: 0.2182 - val_accuracy: 0.8750 - val_loss: 0.7126
# Epoch 182/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8578 - loss: 0.2327 - val_accuracy: 0.8750 - val_loss: 0.5979
# Epoch 183/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9121 - loss: 0.2229 - val_accuracy: 0.8750 - val_loss: 0.5671
# Epoch 184/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8947 - loss: 0.1762 - val_accuracy: 0.8500 - val_loss: 0.6244
# Epoch 185/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9134 - loss: 0.1803 - val_accuracy: 0.8500 - val_loss: 0.6080
# Epoch 186/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9014 - loss: 0.1764 - val_accuracy: 0.9000 - val_loss: 0.5519
# Epoch 187/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8879 - loss: 0.2089 - val_accuracy: 0.8750 - val_loss: 0.6083
# Epoch 188/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8957 - loss: 0.2044 - val_accuracy: 0.8750 - val_loss: 0.6564
# Epoch 189/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8970 - loss: 0.1934 - val_accuracy: 0.8750 - val_loss: 0.6330
# Epoch 190/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9362 - loss: 0.1774 - val_accuracy: 0.8750 - val_loss: 0.6363
# Epoch 191/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9318 - loss: 0.1614 - val_accuracy: 0.8750 - val_loss: 0.6257
# Epoch 192/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9123 - loss: 0.1635 - val_accuracy: 0.8750 - val_loss: 0.6245
# Epoch 193/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9154 - loss: 0.1850 - val_accuracy: 0.8750 - val_loss: 0.6313
# Epoch 194/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8912 - loss: 0.2068 - val_accuracy: 0.8750 - val_loss: 0.7059
# Epoch 195/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9105 - loss: 0.1787 - val_accuracy: 0.8750 - val_loss: 0.6739
# Epoch 196/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9081 - loss: 0.1788 - val_accuracy: 0.8750 - val_loss: 0.6715
# Epoch 197/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9022 - loss: 0.1951 - val_accuracy: 0.9000 - val_loss: 0.6903
# Epoch 198/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9352 - loss: 0.1503 - val_accuracy: 0.8750 - val_loss: 0.7099
# Epoch 199/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9148 - loss: 0.1750 - val_accuracy: 0.9000 - val_loss: 0.7251
# Epoch 200/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9331 - loss: 0.1588 - val_accuracy: 0.8750 - val_loss: 0.6990
# Epoch 201/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9175 - loss: 0.1693 - val_accuracy: 0.8750 - val_loss: 0.7211
# Epoch 202/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8990 - loss: 0.1663 - val_accuracy: 0.8750 - val_loss: 0.7634
# Epoch 203/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9352 - loss: 0.1615 - val_accuracy: 0.8750 - val_loss: 0.7569
# Epoch 204/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9408 - loss: 0.1496 - val_accuracy: 0.8750 - val_loss: 0.7486
# Epoch 205/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9066 - loss: 0.1780 - val_accuracy: 0.8750 - val_loss: 0.7153
# Epoch 206/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9226 - loss: 0.1697 - val_accuracy: 0.8750 - val_loss: 0.7565
# Epoch 207/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9199 - loss: 0.1525 - val_accuracy: 0.8750 - val_loss: 0.8317
# Epoch 208/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8984 - loss: 0.1784 - val_accuracy: 0.8750 - val_loss: 0.7987
# Epoch 209/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9154 - loss: 0.1664 - val_accuracy: 0.9000 - val_loss: 0.6977
# Epoch 210/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9288 - loss: 0.1402 - val_accuracy: 0.8750 - val_loss: 0.8194
# Epoch 211/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9214 - loss: 0.1583 - val_accuracy: 0.9000 - val_loss: 0.8190
# Epoch 212/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9304 - loss: 0.1596 - val_accuracy: 0.9000 - val_loss: 0.7785
# Epoch 213/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.9200 - loss: 0.1794 - val_accuracy: 0.8500 - val_loss: 0.8291
# Epoch 214/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9357 - loss: 0.1688 - val_accuracy: 0.8750 - val_loss: 0.7718
# Epoch 215/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8976 - loss: 0.1724 - val_accuracy: 0.9000 - val_loss: 0.7917
# Epoch 216/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9239 - loss: 0.1615 - val_accuracy: 0.8750 - val_loss: 0.8259
# Epoch 217/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9191 - loss: 0.1520 - val_accuracy: 0.9000 - val_loss: 0.8190
# Epoch 218/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8788 - loss: 0.2014 - val_accuracy: 0.8750 - val_loss: 0.7935
# Epoch 219/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9212 - loss: 0.1783 - val_accuracy: 0.8750 - val_loss: 0.8358
# Epoch 220/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9242 - loss: 0.1586 - val_accuracy: 0.9000 - val_loss: 0.8824
# Epoch 221/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9273 - loss: 0.1627 - val_accuracy: 0.8750 - val_loss: 0.8290
# Epoch 222/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8905 - loss: 0.1717 - val_accuracy: 0.9000 - val_loss: 0.8181
# Epoch 223/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9113 - loss: 0.1658 - val_accuracy: 0.8750 - val_loss: 0.8021
# Epoch 224/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9156 - loss: 0.1597 - val_accuracy: 0.8500 - val_loss: 0.8343
# Epoch 225/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9179 - loss: 0.1582 - val_accuracy: 0.8500 - val_loss: 0.8679
# Epoch 226/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9343 - loss: 0.1385 - val_accuracy: 0.8750 - val_loss: 0.8075
# Epoch 227/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9339 - loss: 0.1349 - val_accuracy: 0.8750 - val_loss: 0.8515
# Epoch 228/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9338 - loss: 0.1419 - val_accuracy: 0.9250 - val_loss: 0.8294
# Epoch 229/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9572 - loss: 0.1358 - val_accuracy: 0.9250 - val_loss: 0.8793
# Epoch 230/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.9183 - loss: 0.1574 - val_accuracy: 0.8750 - val_loss: 0.9019
# Epoch 231/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9200 - loss: 0.1569 - val_accuracy: 0.9000 - val_loss: 0.8600
# Epoch 232/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8845 - loss: 0.1686 - val_accuracy: 0.9000 - val_loss: 0.8647
# Epoch 233/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9252 - loss: 0.1423 - val_accuracy: 0.8750 - val_loss: 0.9722
# Epoch 234/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8937 - loss: 0.1629 - val_accuracy: 0.9000 - val_loss: 0.8971
# Epoch 235/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9023 - loss: 0.1658 - val_accuracy: 0.9000 - val_loss: 0.8790
# Epoch 236/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9165 - loss: 0.1545 - val_accuracy: 0.9000 - val_loss: 0.9328
# Epoch 237/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9458 - loss: 0.1594 - val_accuracy: 0.9000 - val_loss: 0.9110
# Epoch 238/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9165 - loss: 0.1618 - val_accuracy: 0.9000 - val_loss: 0.9550
# Epoch 239/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8997 - loss: 0.1737 - val_accuracy: 0.9000 - val_loss: 0.9421
# Epoch 240/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9353 - loss: 0.1350 - val_accuracy: 0.9000 - val_loss: 0.9072
# Epoch 241/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8935 - loss: 0.1966 - val_accuracy: 0.8500 - val_loss: 0.9833
# Epoch 242/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9329 - loss: 0.1653 - val_accuracy: 0.8750 - val_loss: 0.9848
# Epoch 243/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9342 - loss: 0.1398 - val_accuracy: 0.9000 - val_loss: 0.9504
# Epoch 244/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9200 - loss: 0.1643 - val_accuracy: 0.9000 - val_loss: 0.9210
# Epoch 245/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9158 - loss: 0.1618 - val_accuracy: 0.9000 - val_loss: 0.9353
# Epoch 246/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9145 - loss: 0.1495 - val_accuracy: 0.8750 - val_loss: 0.9591
# Epoch 247/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9069 - loss: 0.1617 - val_accuracy: 0.9250 - val_loss: 0.9626
# Epoch 248/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9104 - loss: 0.1799 - val_accuracy: 0.8750 - val_loss: 0.9914
# Epoch 249/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9018 - loss: 0.1668 - val_accuracy: 0.9000 - val_loss: 0.9692
# Epoch 250/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8997 - loss: 0.1537 - val_accuracy: 0.9250 - val_loss: 0.9615
# Epoch 251/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9229 - loss: 0.1726 - val_accuracy: 0.8750 - val_loss: 0.9941
# Epoch 252/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9289 - loss: 0.1340 - val_accuracy: 0.9000 - val_loss: 1.0001
# Epoch 253/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9430 - loss: 0.1245 - val_accuracy: 0.9000 - val_loss: 0.9892
# Epoch 254/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9378 - loss: 0.1413 - val_accuracy: 0.8750 - val_loss: 1.0233
# Epoch 255/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9391 - loss: 0.1275 - val_accuracy: 0.9000 - val_loss: 1.0107
# Epoch 256/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8970 - loss: 0.1666 - val_accuracy: 0.9000 - val_loss: 1.0061
# Epoch 257/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9217 - loss: 0.1448 - val_accuracy: 0.8750 - val_loss: 1.0515
# Epoch 258/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8884 - loss: 0.1554 - val_accuracy: 0.8750 - val_loss: 1.0295
# Epoch 259/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9455 - loss: 0.1235 - val_accuracy: 0.9000 - val_loss: 0.9817
# Epoch 260/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8953 - loss: 0.1727 - val_accuracy: 0.8750 - val_loss: 1.0567
# Epoch 261/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8987 - loss: 0.1833 - val_accuracy: 0.9000 - val_loss: 1.0246
# Epoch 262/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9282 - loss: 0.1366 - val_accuracy: 0.9000 - val_loss: 1.0537
# Epoch 263/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9286 - loss: 0.1378 - val_accuracy: 0.9000 - val_loss: 1.0878
# Epoch 264/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9100 - loss: 0.1456 - val_accuracy: 0.9000 - val_loss: 1.0570
# Epoch 265/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9069 - loss: 0.1568 - val_accuracy: 0.9250 - val_loss: 1.0097
# Epoch 266/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9293 - loss: 0.1604 - val_accuracy: 0.8750 - val_loss: 1.1005
# Epoch 267/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8951 - loss: 0.1814 - val_accuracy: 0.8750 - val_loss: 1.1215
# Epoch 268/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9113 - loss: 0.1525 - val_accuracy: 0.8750 - val_loss: 1.0401
# Epoch 269/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9193 - loss: 0.1288 - val_accuracy: 0.9000 - val_loss: 1.0105
# Epoch 270/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9393 - loss: 0.1372 - val_accuracy: 0.9000 - val_loss: 1.0963
# Epoch 271/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9472 - loss: 0.1303 - val_accuracy: 0.8750 - val_loss: 1.1324
# Epoch 272/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9191 - loss: 0.1468 - val_accuracy: 0.9000 - val_loss: 1.0191
# Epoch 273/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9235 - loss: 0.1452 - val_accuracy: 0.9000 - val_loss: 0.9995
# Epoch 274/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9507 - loss: 0.1351 - val_accuracy: 0.8750 - val_loss: 1.1642
# Epoch 275/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9118 - loss: 0.1705 - val_accuracy: 0.8750 - val_loss: 1.1174
# Epoch 276/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9115 - loss: 0.1405 - val_accuracy: 0.8750 - val_loss: 1.1008
# Epoch 277/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9115 - loss: 0.2187 - val_accuracy: 0.9000 - val_loss: 0.9278
# Epoch 278/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8671 - loss: 0.3527 - val_accuracy: 0.8750 - val_loss: 1.1826
# Epoch 279/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8273 - loss: 0.3198 - val_accuracy: 0.8500 - val_loss: 1.2768
# Epoch 280/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8668 - loss: 0.2561 - val_accuracy: 0.8750 - val_loss: 0.7910
# Epoch 281/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8176 - loss: 0.3059 - val_accuracy: 0.8750 - val_loss: 0.5305
# Epoch 282/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8760 - loss: 0.2520 - val_accuracy: 0.8500 - val_loss: 0.7370
# Epoch 283/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8857 - loss: 0.2280 - val_accuracy: 0.8750 - val_loss: 0.9005
# Epoch 284/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9060 - loss: 0.1750 - val_accuracy: 0.8750 - val_loss: 0.8888
# Epoch 285/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8737 - loss: 0.1955 - val_accuracy: 0.8500 - val_loss: 0.8125
# Epoch 286/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9115 - loss: 0.1594 - val_accuracy: 0.8750 - val_loss: 0.8307
# Epoch 287/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8556 - loss: 0.2038 - val_accuracy: 0.8750 - val_loss: 0.8641
# Epoch 288/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8982 - loss: 0.1991 - val_accuracy: 0.8750 - val_loss: 0.8923
# Epoch 289/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8694 - loss: 0.2011 - val_accuracy: 0.8750 - val_loss: 0.8662
# Epoch 290/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8985 - loss: 0.1916 - val_accuracy: 0.8750 - val_loss: 0.8612
# Epoch 291/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9016 - loss: 0.1715 - val_accuracy: 0.8750 - val_loss: 0.8928
# Epoch 292/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9088 - loss: 0.1519 - val_accuracy: 0.8750 - val_loss: 0.9092
# Epoch 293/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8779 - loss: 0.1908 - val_accuracy: 0.8750 - val_loss: 0.9199
# Epoch 294/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9056 - loss: 0.1567 - val_accuracy: 0.9000 - val_loss: 0.8830
# Epoch 295/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9186 - loss: 0.1688 - val_accuracy: 0.8750 - val_loss: 0.9262
# Epoch 296/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.8882 - loss: 0.1746 - val_accuracy: 0.9000 - val_loss: 0.9067
# Epoch 297/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9137 - loss: 0.1651 - val_accuracy: 0.8750 - val_loss: 0.8708
# Epoch 298/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8964 - loss: 0.1845 - val_accuracy: 0.8750 - val_loss: 0.9075
# Epoch 299/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8831 - loss: 0.1615 - val_accuracy: 0.8750 - val_loss: 0.8648
# Epoch 300/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8875 - loss: 0.1672 - val_accuracy: 0.9000 - val_loss: 0.8713
# Epoch 301/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8744 - loss: 0.1877 - val_accuracy: 0.9000 - val_loss: 0.9047
# Epoch 302/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9244 - loss: 0.1513 - val_accuracy: 0.8750 - val_loss: 0.9149
# Epoch 303/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9138 - loss: 0.1580 - val_accuracy: 0.8750 - val_loss: 0.9122
# Epoch 304/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9153 - loss: 0.1734 - val_accuracy: 0.9000 - val_loss: 0.8973
# Epoch 305/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9230 - loss: 0.1339 - val_accuracy: 0.9000 - val_loss: 0.8989
# Epoch 306/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9095 - loss: 0.1338 - val_accuracy: 0.9000 - val_loss: 0.9383
# Epoch 307/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.9127 - loss: 0.1693 - val_accuracy: 0.8750 - val_loss: 0.9402
# Epoch 308/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9004 - loss: 0.1683 - val_accuracy: 0.9000 - val_loss: 0.9588
# Epoch 309/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9079 - loss: 0.1729 - val_accuracy: 0.9000 - val_loss: 0.9225
# Epoch 310/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9036 - loss: 0.1679 - val_accuracy: 0.9000 - val_loss: 0.9295
# Epoch 311/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9081 - loss: 0.1494 - val_accuracy: 0.9000 - val_loss: 0.9389
# Epoch 312/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9141 - loss: 0.1619 - val_accuracy: 0.9000 - val_loss: 0.8995
# Epoch 313/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9231 - loss: 0.1564 - val_accuracy: 0.9000 - val_loss: 0.9241
# Epoch 314/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9308 - loss: 0.1532 - val_accuracy: 0.8750 - val_loss: 0.9443
# Epoch 315/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8958 - loss: 0.1678 - val_accuracy: 0.8750 - val_loss: 0.9079
# Epoch 316/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9114 - loss: 0.1657 - val_accuracy: 0.9000 - val_loss: 0.9217
# Epoch 317/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8821 - loss: 0.1784 - val_accuracy: 0.9000 - val_loss: 0.9628
# Epoch 318/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9049 - loss: 0.1779 - val_accuracy: 0.8750 - val_loss: 0.9375
# Epoch 319/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9209 - loss: 0.1585 - val_accuracy: 0.8750 - val_loss: 0.9689
# Epoch 320/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9171 - loss: 0.1579 - val_accuracy: 0.8750 - val_loss: 0.9556
# Epoch 321/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9040 - loss: 0.1722 - val_accuracy: 0.9000 - val_loss: 0.9643
# Epoch 322/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9252 - loss: 0.1418 - val_accuracy: 0.9000 - val_loss: 0.9696
# Epoch 323/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9005 - loss: 0.1757 - val_accuracy: 0.8750 - val_loss: 0.9921
# Epoch 324/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9295 - loss: 0.1411 - val_accuracy: 0.8750 - val_loss: 0.9838
# Epoch 325/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9222 - loss: 0.1363 - val_accuracy: 0.8750 - val_loss: 0.9744
# Epoch 326/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9157 - loss: 0.1467 - val_accuracy: 0.9000 - val_loss: 0.9652
# Epoch 327/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9023 - loss: 0.1682 - val_accuracy: 0.9000 - val_loss: 1.0048
# Epoch 328/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9035 - loss: 0.1787 - val_accuracy: 0.9000 - val_loss: 1.0013
# Epoch 329/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9227 - loss: 0.1390 - val_accuracy: 0.9000 - val_loss: 1.0001
# Epoch 330/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9101 - loss: 0.1527 - val_accuracy: 0.8750 - val_loss: 1.0262
# Epoch 331/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9030 - loss: 0.1653 - val_accuracy: 0.8750 - val_loss: 0.9914
# Epoch 332/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8996 - loss: 0.1640 - val_accuracy: 0.8750 - val_loss: 0.9713
# Epoch 333/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9035 - loss: 0.1883 - val_accuracy: 0.8750 - val_loss: 0.9777
# Epoch 334/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9093 - loss: 0.1731 - val_accuracy: 0.8750 - val_loss: 1.0289
# Epoch 335/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9309 - loss: 0.1605 - val_accuracy: 0.8750 - val_loss: 1.0843
# Epoch 336/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9135 - loss: 0.1584 - val_accuracy: 0.8750 - val_loss: 1.0698
# Epoch 337/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9032 - loss: 0.1568 - val_accuracy: 0.9250 - val_loss: 1.0108
# Epoch 338/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9103 - loss: 0.1510 - val_accuracy: 0.9000 - val_loss: 1.0551
# Epoch 339/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9279 - loss: 0.1485 - val_accuracy: 0.9250 - val_loss: 1.0221
# Epoch 340/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9148 - loss: 0.1721 - val_accuracy: 0.9250 - val_loss: 1.0276
# Epoch 341/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9035 - loss: 0.1649 - val_accuracy: 0.9250 - val_loss: 1.0599
# Epoch 342/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9190 - loss: 0.1511 - val_accuracy: 0.9000 - val_loss: 1.0657
# Epoch 343/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9365 - loss: 0.1341 - val_accuracy: 0.9000 - val_loss: 1.0954
# Epoch 344/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.8766 - loss: 0.2038 - val_accuracy: 0.8750 - val_loss: 1.0333
# Epoch 345/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9026 - loss: 0.1641 - val_accuracy: 0.9000 - val_loss: 1.0390
# Epoch 346/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9148 - loss: 0.1559 - val_accuracy: 0.8750 - val_loss: 1.0688
# Epoch 347/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9122 - loss: 0.1384 - val_accuracy: 0.8750 - val_loss: 1.0453
# Epoch 348/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9096 - loss: 0.1602 - val_accuracy: 0.8750 - val_loss: 1.0684
# Epoch 349/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9269 - loss: 0.1556 - val_accuracy: 0.8750 - val_loss: 1.0992
# Epoch 350/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9178 - loss: 0.1563 - val_accuracy: 0.8750 - val_loss: 1.1067
# Epoch 351/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9268 - loss: 0.1632 - val_accuracy: 0.8750 - val_loss: 1.0751
# Epoch 352/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9006 - loss: 0.1676 - val_accuracy: 0.9000 - val_loss: 1.0915
# Epoch 353/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - accuracy: 0.8730 - loss: 0.1696 - val_accuracy: 0.9000 - val_loss: 1.0900
# Epoch 354/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.8975 - loss: 0.1609 - val_accuracy: 0.9000 - val_loss: 1.0776
# Epoch 355/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9112 - loss: 0.1672 - val_accuracy: 0.8750 - val_loss: 1.0982
# Epoch 356/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9195 - loss: 0.1443 - val_accuracy: 0.8750 - val_loss: 1.1498
# Epoch 357/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9148 - loss: 0.1641 - val_accuracy: 0.9000 - val_loss: 1.0926
# Epoch 358/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9075 - loss: 0.1630 - val_accuracy: 0.9000 - val_loss: 1.0858
# Epoch 359/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9204 - loss: 0.1370 - val_accuracy: 0.9250 - val_loss: 1.1115
# Epoch 360/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9215 - loss: 0.1620 - val_accuracy: 0.9000 - val_loss: 1.0757
# Epoch 361/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9320 - loss: 0.1384 - val_accuracy: 0.9000 - val_loss: 1.0864
# Epoch 362/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8800 - loss: 0.1944 - val_accuracy: 0.9250 - val_loss: 1.1118
# Epoch 363/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9060 - loss: 0.1797 - val_accuracy: 0.9000 - val_loss: 1.1362
# Epoch 364/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9022 - loss: 0.1765 - val_accuracy: 0.8750 - val_loss: 1.1225
# Epoch 365/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9321 - loss: 0.1411 - val_accuracy: 0.9000 - val_loss: 1.1530
# Epoch 366/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9066 - loss: 0.1599 - val_accuracy: 0.9000 - val_loss: 1.1234
# Epoch 367/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9200 - loss: 0.1540 - val_accuracy: 0.9000 - val_loss: 1.1456
# Epoch 368/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9165 - loss: 0.1544 - val_accuracy: 0.9000 - val_loss: 1.1494
# Epoch 369/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9403 - loss: 0.1415 - val_accuracy: 0.8750 - val_loss: 1.1783
# Epoch 370/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9355 - loss: 0.1400 - val_accuracy: 0.9000 - val_loss: 1.1507
# Epoch 371/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9243 - loss: 0.1485 - val_accuracy: 0.9250 - val_loss: 1.1186
# Epoch 372/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9255 - loss: 0.1490 - val_accuracy: 0.8750 - val_loss: 1.1448
# Epoch 373/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9281 - loss: 0.1343 - val_accuracy: 0.8750 - val_loss: 1.2046
# Epoch 374/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step - accuracy: 0.9506 - loss: 0.1106 - val_accuracy: 0.9000 - val_loss: 1.1713
# Epoch 375/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9030 - loss: 0.1618 - val_accuracy: 0.9250 - val_loss: 1.1339
# Epoch 376/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9073 - loss: 0.1866 - val_accuracy: 0.9000 - val_loss: 1.2196
# Epoch 377/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9342 - loss: 0.1596 - val_accuracy: 0.9000 - val_loss: 1.1709
# Epoch 378/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9434 - loss: 0.1292 - val_accuracy: 0.9000 - val_loss: 1.2035
# Epoch 379/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8859 - loss: 0.1670 - val_accuracy: 0.8750 - val_loss: 1.2379
# Epoch 380/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9275 - loss: 0.1503 - val_accuracy: 0.9000 - val_loss: 1.2289
# Epoch 381/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9337 - loss: 0.1556 - val_accuracy: 0.8750 - val_loss: 1.2426
# Epoch 382/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8751 - loss: 0.1787 - val_accuracy: 0.9000 - val_loss: 1.1734
# Epoch 383/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9109 - loss: 0.1678 - val_accuracy: 0.9000 - val_loss: 1.1776
# Epoch 384/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.8941 - loss: 0.1826 - val_accuracy: 0.8750 - val_loss: 1.2720
# Epoch 385/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9025 - loss: 0.1585 - val_accuracy: 0.8750 - val_loss: 1.2621
# Epoch 386/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9186 - loss: 0.1583 - val_accuracy: 0.9000 - val_loss: 1.1836
# Epoch 387/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9276 - loss: 0.1530 - val_accuracy: 0.8750 - val_loss: 1.1910
# Epoch 388/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9431 - loss: 0.1281 - val_accuracy: 0.8750 - val_loss: 1.2288
# Epoch 389/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9247 - loss: 0.1406 - val_accuracy: 0.8750 - val_loss: 1.2165
# Epoch 390/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9111 - loss: 0.1403 - val_accuracy: 0.8750 - val_loss: 1.2132
# Epoch 391/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9178 - loss: 0.1392 - val_accuracy: 0.8750 - val_loss: 1.2397
# Epoch 392/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9187 - loss: 0.1588 - val_accuracy: 0.8750 - val_loss: 1.2497
# Epoch 393/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9402 - loss: 0.1407 - val_accuracy: 0.8750 - val_loss: 1.2904
# Epoch 394/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - accuracy: 0.9341 - loss: 0.1463 - val_accuracy: 0.9000 - val_loss: 1.2862
# Epoch 395/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9233 - loss: 0.1539 - val_accuracy: 0.9000 - val_loss: 1.2696
# Epoch 396/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.9102 - loss: 0.1674 - val_accuracy: 0.8750 - val_loss: 1.2395
# Epoch 397/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9372 - loss: 0.1271 - val_accuracy: 0.8750 - val_loss: 1.2540
# Epoch 398/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9433 - loss: 0.1398 - val_accuracy: 0.9000 - val_loss: 1.2671
# Epoch 399/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9168 - loss: 0.1435 - val_accuracy: 0.9000 - val_loss: 1.2767
# Epoch 400/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9306 - loss: 0.1517 - val_accuracy: 0.8750 - val_loss: 1.2666
# Epoch 401/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9355 - loss: 0.1434 - val_accuracy: 0.8750 - val_loss: 1.2673
# Epoch 402/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9151 - loss: 0.1496 - val_accuracy: 0.9000 - val_loss: 1.2740
# Epoch 403/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9353 - loss: 0.1532 - val_accuracy: 0.8750 - val_loss: 1.2815
# Epoch 404/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9477 - loss: 0.1228 - val_accuracy: 0.8750 - val_loss: 1.2928
# Epoch 405/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9207 - loss: 0.1472 - val_accuracy: 0.9000 - val_loss: 1.2993
# Epoch 406/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9345 - loss: 0.1455 - val_accuracy: 0.9000 - val_loss: 1.2918
# Epoch 407/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9372 - loss: 0.1270 - val_accuracy: 0.9000 - val_loss: 1.2753
# Epoch 408/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9278 - loss: 0.1497 - val_accuracy: 0.9000 - val_loss: 1.2647
# Epoch 409/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8977 - loss: 0.1575 - val_accuracy: 0.9000 - val_loss: 1.3037
# Epoch 410/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9522 - loss: 0.1287 - val_accuracy: 0.9000 - val_loss: 1.3316
# Epoch 411/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9391 - loss: 0.1170 - val_accuracy: 0.9000 - val_loss: 1.2983
# Epoch 412/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9298 - loss: 0.1541 - val_accuracy: 0.9000 - val_loss: 1.2741
# Epoch 413/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9343 - loss: 0.1139 - val_accuracy: 0.8750 - val_loss: 1.2924
# Epoch 414/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.9091 - loss: 0.1569 - val_accuracy: 0.8750 - val_loss: 1.3473
# Epoch 415/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9303 - loss: 0.1387 - val_accuracy: 0.8750 - val_loss: 1.3335
# Epoch 416/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9563 - loss: 0.1282 - val_accuracy: 0.9000 - val_loss: 1.3207
# Epoch 417/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9306 - loss: 0.1310 - val_accuracy: 0.8750 - val_loss: 1.3590
# Epoch 418/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9380 - loss: 0.1200 - val_accuracy: 0.9000 - val_loss: 1.3770
# Epoch 419/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9389 - loss: 0.1276 - val_accuracy: 0.9000 - val_loss: 1.3897
# Epoch 420/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9579 - loss: 0.1205 - val_accuracy: 0.9000 - val_loss: 1.3638
# Epoch 421/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9536 - loss: 0.1201 - val_accuracy: 0.9000 - val_loss: 1.3452
# Epoch 422/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9197 - loss: 0.1187 - val_accuracy: 0.9000 - val_loss: 1.3658
# Epoch 423/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9385 - loss: 0.1382 - val_accuracy: 0.9000 - val_loss: 1.3747
# Epoch 424/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9652 - loss: 0.1143 - val_accuracy: 0.8750 - val_loss: 1.3425
# Epoch 425/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9441 - loss: 0.1384 - val_accuracy: 0.8750 - val_loss: 1.3692
# Epoch 426/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9323 - loss: 0.1387 - val_accuracy: 0.8750 - val_loss: 1.4089
# Epoch 427/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9552 - loss: 0.1286 - val_accuracy: 0.8750 - val_loss: 1.4166
# Epoch 428/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9532 - loss: 0.1055 - val_accuracy: 0.8750 - val_loss: 1.3694
# Epoch 429/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9415 - loss: 0.1153 - val_accuracy: 0.8750 - val_loss: 1.3612
# Epoch 430/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9345 - loss: 0.1115 - val_accuracy: 0.8750 - val_loss: 1.3836
# Epoch 431/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9400 - loss: 0.1197 - val_accuracy: 0.9000 - val_loss: 1.3819
# Epoch 432/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9549 - loss: 0.1090 - val_accuracy: 0.9000 - val_loss: 1.3591
# Epoch 433/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.9388 - loss: 0.1167 - val_accuracy: 0.9000 - val_loss: 1.3841
# Epoch 434/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9354 - loss: 0.1169 - val_accuracy: 0.9000 - val_loss: 1.3935
# Epoch 435/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9422 - loss: 0.1283 - val_accuracy: 0.8750 - val_loss: 1.3824
# Epoch 436/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9254 - loss: 0.1339 - val_accuracy: 0.9000 - val_loss: 1.3994
# Epoch 437/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9415 - loss: 0.1177 - val_accuracy: 0.8750 - val_loss: 1.4012
# Epoch 438/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9286 - loss: 0.1217 - val_accuracy: 0.8750 - val_loss: 1.4174
# Epoch 439/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9497 - loss: 0.1213 - val_accuracy: 0.8750 - val_loss: 1.3727
# Epoch 440/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9042 - loss: 0.1456 - val_accuracy: 0.8750 - val_loss: 1.3538
# Epoch 441/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9418 - loss: 0.1351 - val_accuracy: 0.9000 - val_loss: 1.3881
# Epoch 442/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9286 - loss: 0.1366 - val_accuracy: 0.9000 - val_loss: 1.4347
# Epoch 443/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8889 - loss: 0.1505 - val_accuracy: 0.8750 - val_loss: 1.4473
# Epoch 444/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9298 - loss: 0.1365 - val_accuracy: 0.9000 - val_loss: 1.4067
# Epoch 445/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9199 - loss: 0.1250 - val_accuracy: 0.9000 - val_loss: 1.3820
# Epoch 446/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9166 - loss: 0.1294 - val_accuracy: 0.8750 - val_loss: 1.4084
# Epoch 447/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9354 - loss: 0.1093 - val_accuracy: 0.8750 - val_loss: 1.4312
# Epoch 448/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9285 - loss: 0.1222 - val_accuracy: 0.8750 - val_loss: 1.4550
# Epoch 449/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.9278 - loss: 0.1209 - val_accuracy: 0.8750 - val_loss: 1.4339
# Epoch 450/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9496 - loss: 0.1207 - val_accuracy: 0.9000 - val_loss: 1.4013
# Epoch 451/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.9383 - loss: 0.1227 - val_accuracy: 0.9000 - val_loss: 1.4036
# Epoch 452/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9333 - loss: 0.1252 - val_accuracy: 0.8750 - val_loss: 1.3942
# Epoch 453/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9207 - loss: 0.1344 - val_accuracy: 0.8750 - val_loss: 1.4109
# Epoch 454/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9300 - loss: 0.1085 - val_accuracy: 0.8750 - val_loss: 1.4547
# Epoch 455/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9208 - loss: 0.1225 - val_accuracy: 0.8750 - val_loss: 1.4562
# Epoch 456/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8959 - loss: 0.1591 - val_accuracy: 0.8750 - val_loss: 1.4935
# Epoch 457/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9527 - loss: 0.1088 - val_accuracy: 0.8750 - val_loss: 1.4853
# Epoch 458/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 0.9406 - loss: 0.1070 - val_accuracy: 0.8750 - val_loss: 1.4301
# Epoch 459/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9475 - loss: 0.1193 - val_accuracy: 0.9000 - val_loss: 1.4615
# Epoch 460/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9674 - loss: 0.1062 - val_accuracy: 0.8500 - val_loss: 1.4798
# Epoch 461/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9575 - loss: 0.1182 - val_accuracy: 0.8750 - val_loss: 1.4615
# Epoch 462/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9180 - loss: 0.1256 - val_accuracy: 0.8750 - val_loss: 1.5182
# Epoch 463/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9274 - loss: 0.1434 - val_accuracy: 0.8750 - val_loss: 1.5147
# Epoch 464/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9570 - loss: 0.0993 - val_accuracy: 0.9000 - val_loss: 1.4938
# Epoch 465/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9612 - loss: 0.1143 - val_accuracy: 0.8750 - val_loss: 1.5071
# Epoch 466/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.9127 - loss: 0.1544 - val_accuracy: 0.8750 - val_loss: 1.5109
# Epoch 467/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9345 - loss: 0.1323 - val_accuracy: 0.8500 - val_loss: 1.4836
# Epoch 468/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 0.9413 - loss: 0.1064 - val_accuracy: 0.9000 - val_loss: 1.5016
# Epoch 469/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9545 - loss: 0.1179 - val_accuracy: 0.9000 - val_loss: 1.5080
# Epoch 470/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9306 - loss: 0.1164 - val_accuracy: 0.8750 - val_loss: 1.5542
# Epoch 471/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9255 - loss: 0.1299 - val_accuracy: 0.8750 - val_loss: 1.5746
# Epoch 472/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9272 - loss: 0.1291 - val_accuracy: 0.9000 - val_loss: 1.4761
# Epoch 473/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9357 - loss: 0.1380 - val_accuracy: 0.9000 - val_loss: 1.4407
# Epoch 474/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 0.9512 - loss: 0.1219 - val_accuracy: 0.9000 - val_loss: 1.4751
# Epoch 475/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9444 - loss: 0.1257 - val_accuracy: 0.8500 - val_loss: 1.5547
# Epoch 476/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9171 - loss: 0.1752 - val_accuracy: 0.9000 - val_loss: 1.3730
# Epoch 477/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8720 - loss: 0.4112 - val_accuracy: 0.8750 - val_loss: 1.6878
# Epoch 478/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8487 - loss: 0.2245 - val_accuracy: 0.8750 - val_loss: 1.7509
# Epoch 479/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9278 - loss: 0.1499 - val_accuracy: 0.8500 - val_loss: 1.6587
# Epoch 480/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.8668 - loss: 0.2270 - val_accuracy: 0.8500 - val_loss: 1.8815
# Epoch 481/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9056 - loss: 0.2011 - val_accuracy: 0.8500 - val_loss: 1.5333
# Epoch 482/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.9003 - loss: 0.1871 - val_accuracy: 0.8500 - val_loss: 1.2843
# Epoch 483/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9000 - loss: 0.1650 - val_accuracy: 0.8500 - val_loss: 1.5798
# Epoch 484/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8636 - loss: 0.2529 - val_accuracy: 0.8750 - val_loss: 1.5652
# Epoch 485/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.9051 - loss: 0.2011 - val_accuracy: 0.8500 - val_loss: 1.2317
# Epoch 486/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8852 - loss: 0.1935 - val_accuracy: 0.8750 - val_loss: 1.4153
# Epoch 487/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9080 - loss: 0.1456 - val_accuracy: 0.8500 - val_loss: 1.5033
# Epoch 488/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.8991 - loss: 0.1745 - val_accuracy: 0.8500 - val_loss: 1.3692
# Epoch 489/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9141 - loss: 0.2000 - val_accuracy: 0.8750 - val_loss: 1.5518
# Epoch 490/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 0.9040 - loss: 0.1823 - val_accuracy: 0.8750 - val_loss: 1.5046
# Epoch 491/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 0.9286 - loss: 0.1384 - val_accuracy: 0.8500 - val_loss: 1.5106
# Epoch 492/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9221 - loss: 0.1631 - val_accuracy: 0.8500 - val_loss: 1.5678
# Epoch 493/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9144 - loss: 0.1456 - val_accuracy: 0.8750 - val_loss: 1.5654
# Epoch 494/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9264 - loss: 0.1592 - val_accuracy: 0.8500 - val_loss: 1.5355
# Epoch 495/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9503 - loss: 0.1440 - val_accuracy: 0.8750 - val_loss: 1.5225
# Epoch 496/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9165 - loss: 0.1519 - val_accuracy: 0.8750 - val_loss: 1.6216
# Epoch 497/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9102 - loss: 0.1392 - val_accuracy: 0.8750 - val_loss: 1.6084
# Epoch 498/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.9347 - loss: 0.1273 - val_accuracy: 0.8750 - val_loss: 1.5677
# Epoch 499/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9248 - loss: 0.1603 - val_accuracy: 0.8750 - val_loss: 1.6526
# Epoch 500/500
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9099 - loss: 0.1644 - val_accuracy: 0.8750 - val_loss: 1.6245

# %%
# Plot the decision region
plot_decision_regions(X, y, clf=model, legend=2);
# Out:
# 9600/9600 ━━━━━━━━━━━━━━━━━━━━ 7s 762us/step

# %% [markdown]
# #### **Conclusion**
# The first model with linear activations can only separate the data with a straight line, limiting its ability to handle complex patterns.
# The second model with ReLU activations in the hidden layers can create a more flexible and complex decision boundary, leading to better performance on non-linear data distributions.

# %% [markdown]
# ## **Characteristics of an Ideal Activation Function**
# An ideal activation function should have the following characteristics:
#
# 1. **Non-Linear**: Non-linearity allows the network to model complex patterns and relationships in the data, enabling the network to learn and approximate any function, not just linear relationships.
# 2. **Differentiable**: Differentiability ensures that the activation function can be used in gradient-based optimization methods, such as backpropagation.
# 3. **Computationally Inexpensive**: The activation function should be computationally efficient to evaluate, especially for large-scale neural networks, to ensure that training and inference are feasible and fast.
# 4. **Zero-Centered**: A zero-centered activation function outputs values that are centered around zero, helping to ensure that the gradients are balanced and preventing one side of the weights from dominating.
# 5. **Non-Saturating**: Non-saturating activation functions do not suffer from the vanishing gradient problem, where gradients become very small, leading to slow learning or no learning at all. For example, functions like ReLU do not saturate in the positive region, allowing gradients to remain significant, thus helping deep networks to continue learning effectively as the number of layers increases.
# 6. **Smooth**: Smoothness ensures that the activation function doesn’t introduce any abrupt changes in the output, which can help in more stable learning.
# 7. **Monotonic**: A monotonic function ensures that the gradient doesn't change signs, which can simplify the optimization process.

# %% [markdown]
# ## **Different Types of Activation Functions**
# ### **Sigmoid Activation Function**
# The sigmoid activation function is a popular activation function used in neural networks, especially in binary classification tasks. It is defined by the following formula:
# $$\sigma(x) = \frac{1}{1 + e^{-x}}$$
# where $x$ is the input to the neuron.
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*6A3A_rt4YmumHusvTvVTxw.png" width="60%">
#
#
# **Characteristics of the Sigmoid Activation Function:**
#
# 1. **Output Range**: The output of the sigmoid function ranges between 0 and 1. It is useful for models that need to predict probabilities or binary outcomes.
#
# 2. **Non-Linearity**: The sigmoid function is non-linear, allowing the network to capture complex patterns.
#
# 3. **Smooth and Differentiable**: The sigmoid function is smooth and differentiable, making it suitable for gradient-based optimization methods like backpropagation.
#
# 4. **Saturating**: The sigmoid function can saturate, meaning that for very large or very small input values, the output approaches 1 or 0, respectively. This can lead to very small gradients (vanishing gradients), slowing down learning in deep networks.
#
# 5. **Not Zero-Centered**: The output is always positive, which can lead to inefficiencies during training since the gradients will also always be positive or always negative.
#
# 6. **Applications**: Commonly used in the output layer of binary classification models. Also used in the hidden layers of older neural network models, though ReLU and its variants are more commonly used now due to better performance in deeper networks.

# %% [markdown]
# ### **Tanh Activation Function**
# The tanh (hyperbolic tangent) activation function is another widely used activation function in neural networks. It is defined by the following formula:
# $$\text{tanh}(x) = \frac{(e^x - e^{-x})}{e^x + e^{-x}}$$
# where $x$ is the input to the neuron.
#
# <img src="https://qph.cf2.quoracdn.net/main-qimg-f1baf29cfdb09202b18e2179f4f41bfc" width="60%">
#
# **Characteristics of the Tanh Activation Function:**
#
# 1. **Output Range**: The output of the tanh function ranges between $-1$ and $1$. It provides a symmetric output centered around zero, which is an advantage over the sigmoid function.
#
# 2. **Non-Linearity**: Like the sigmoid function, tanh is non-linear, allowing the network to model complex relationships.
#
# 3.  **Smooth and Differentiable**: The tanh function is smooth and differentiable, making it suitable for gradient-based optimization methods like backpropagation.
#
# 4. **Zero-Centered**: Unlike the sigmoid function, tanh is zero-centered, meaning that the output is symmetrically distributed around zero. This helps in balancing the gradients and making learning more efficient.
#
# 5. **Saturating**: Tanh can also saturate, meaning for very large or very small input values, the output approaches 1 or -1. This can lead to the vanishing gradient problem, similar to the sigmoid function.
#
# 6. **Applications**: Often used in hidden layers of neural networks. It was more commonly used before ReLU and its variants became popular due to better performance in deep networks.

# %% [markdown]
# ### **ReLU Activation Function**
# The ReLU (Rectified Linear Unit) activation function is one of the most widely used activation functions in modern neural networks, especially in deep learning. It is defined by the following formula:
# $$\text{ReLU}(x) = \text{max}(0, x)$$
# where $ x $ is the input to the neuron.
#
# <img src="https://wikidocs.net/images/page/164363/Fig_19_deivrelu.jpg" width="60%">
#
# **Characteristics of the ReLU Activation Function:**
#
# 1. **Output Range**: The output of the ReLU function ranges from $0$ to $\infty$. The function outputs zero for any negative input and the input itself for any positive input.
#
# 2. **Non-Linearity**: ReLU is non-linear, allowing the network to model complex patterns and interactions between features.
#
# 3. **Computationally Efficient**: ReLU is simple to compute since it only involves a comparison operation, making it computationally efficient.
#
# 4. **Non-Saturating**: Unlike sigmoid and tanh, ReLU does not saturate for positive inputs, which helps avoid the vanishing gradient problem. This allows for faster learning in deep networks.
#
# 5. **Not Zero-Centered**: The output of ReLU is not zero-centered since it only outputs non-negative values. This can sometimes cause inefficiencies in learning, but these are usually outweighed by the benefits.
#
# 6. **Sparse Activation**: ReLU leads to sparse activation, meaning that in a large network, many neurons will output zero for a given input, which can help with computational efficiency and reducing overfitting.
#
# 7. **Potential Issue (Dying ReLU)**: A potential drawback of ReLU is the "dying ReLU" problem, where neurons can get stuck outputting zero and stop learning. This happens if the weights are updated in such a way that they always produce a negative input for certain neurons.
#
# 8. **Variants**: Variants like Leaky ReLU, Parametric ReLU (PReLU), and ELU have been introduced to address the dying ReLU problem by allowing a small, non-zero gradient for negative inputs.

# %% [markdown]
# ### **Variants of ReLU Activation**
#
# #### **The Dying ReLU Problem**
# The Dying ReLU problem occurs in neural networks when neurons become inactive and only output zero for any input, effectively "dying" and ceasing to contribute to the learning process. This problem arises due to the nature of the ReLU activation function, especially during the training process when weights are updated via backpropagation.
#
# During training, if a large number of neurons in a layer consistently receive negative inputs, these neurons will output zero and their gradients will also be zero. Consequently, these neurons do not contribute to the model's learning since their weights do not get updated (because the gradient of ReLU for $ x \leq 0 $ is zero). If too many neurons "die" this way, it can severely degrade the model's performance.
#
# **Mathematical Formulation:**
#
# - Let $a_i$ be the activation of the $(i)$-th neuron after applying ReLU:
#     $$a_i = \text{ReLU}(z_i) = \max(0, z_i)$$
#     where $z_i = w_i^Tx + b$, with $w_i$ being the weight vector, $x$ the input, and $b_i$ the bias.
#
# - The gradient of the loss function $L$ with respect to input $z_i$ of ReLU is:
#     $$
#     \frac{\partial L}{\partial z_i} = \begin{cases}
#     \frac{\partial L}{\partial a_i} & \text{if } z_i > 0 \\
#     0 & \text{if } z_i \leq 0
#     \end{cases}
#     $$
#
# - If $ z_i \leq 0 $, the gradient becomes zero, leading to no weight update:
#   $$
#   \Delta w_i = -\eta \frac{\partial L}{\partial w_i} = 0
#   $$
#   where $ \eta $ is the learning rate.

# %% [markdown]
# #### 1. **Leaky ReLU:**
# Leaky ReLU is a variant of the Rectified Linear Unit (ReLU) activation function designed to address the Dying ReLU problem. It is defined by the following formula:
# $$
#     \text{Leaky ReLU}(x) = \begin{cases}
#     x & \text{if } x > 0 \\
#     0.01 x & \text{if } x \leq 0
#     \end{cases}
# $$
# where $0.01$ is a small positive constant.
#
# <img src="https://www.researchgate.net/publication/358306930/figure/fig2/AS:1119417702318091@1643901386378/ReLU-activation-function-vs-LeakyReLU-activation-function_W640.jpg" width="60%">
#
# <img src="https://miro.medium.com/v2/resize:fit:2000/1*Ho3rj6FyQTdbQdvOeyACXA.png" width="60%">
#
# **Characteristics:**
# 1. **Non-Linearity**: Like ReLU, Leaky ReLU is non-linear, allowing the network to capture complex patterns.
#
# 2. **Non-Zero Gradient for Negative Inputs**: Unlike standard ReLU, which outputs zero for negative inputs, Leaky ReLU assigns a small, non-zero slope for negative inputs. This ensures that the neuron continues to learn, as the gradient is non-zero for negative inputs.
#
# 3. **Output Range**: The output of Leaky ReLU can range from $-\infty$ to $ \infty $, depending on the input.
#
# 4. **Avoiding the Dying ReLU Problem**: By allowing a small negative slope for negative inputs, Leaky ReLU prevents neurons from getting stuck and "dying" (outputting zero for all inputs).
#
# 5. **Differentiable**: The Leaky ReLU function is differentiable, making it compatible with gradient-based optimization methods like backpropagation.
#
# 6. **Zero-Centered**: Leaky ReLU is not zero-centered, as it outputs positive values for positive inputs and negative values (though small) for negative inputs. However, it still performs well in practice.

# %% [markdown]
# #### 2. **Parametric ReLU (PReLU):**
# Parametric ReLU (PReLU) is a variant of the ReLU (Rectified Linear Unit) activation function designed to improve upon the standard ReLU and its variant, Leaky ReLU, by allowing the slope of the function for negative inputs to be learned during training. This provides more flexibility and adaptability to the network. It is defined by the following formula:
#
# $$
#     \text{PReLU}(x) = \begin{cases}
#     x & \text{if } x > 0 \\
#     \alpha_i x & \text{if } x \leq 0
#     \end{cases}
# $$
# where $ \alpha_i $ is a learnable parameter for each neuron, rather than a fixed constant like in Leaky ReLU.
#
# <img src="https://blogs.brain-mentors.com/content/images/2022/06/2813863991-5e720eab30026_articlex.png" width="60%">
#
# **Characteristics:**
# 1. **Learnable Slope**: Unlike Leaky ReLU, where the slope for negative inputs $( \alpha )$ is fixed, PReLU allows this slope to be a parameter that is learned from the data during the training process. This means each neuron can have its own slope $ \alpha_i $ for negative inputs, allowing the network to adapt more effectively to the specific data.
#
# 2. **Non-Linearity**: Like ReLU and Leaky ReLU, PReLU is non-linear, which enables the network to model complex relationships in the data.
#
# 3. **Output Range**: The output of PReLU can range from $-\infty$ to $ \infty $, depending on the input.
#
# 4. **Avoids the Dying ReLU Problem**: Similar to Leaky ReLU, PReLU mitigates the Dying ReLU problem by ensuring that neurons have a non-zero gradient even for negative inputs. However, it improves upon Leaky ReLU by allowing the network to learn the best slope for negative values during training.
#
# 5. **Differentiable**: PReLU is differentiable, making it compatible with gradient-based optimization methods like backpropagation.
#
# 6. **Zero-Centered**: Like ReLU and Leaky ReLU, PReLU is not zero-centered, meaning it can output positive or negative values depending on the input.

# %% [markdown]
# #### 3. **Exponential Linear Unit (ELU):**
# The Exponential Linear Unit (ELU) is an activation function designed to address some of the limitations of the ReLU (Rectified Linear Unit) and its variants. ELU helps to improve the learning dynamics of deep neural networks by introducing a smoother transition from negative to positive values, which can lead to faster learning and better performance. It is defined by the following formula:
# $$
# \text{ELU}(x) = \begin{cases}
#     x & \text{if } x > 0 \\
#     \alpha (e^x - 1) & \text{if } x \leq 0
# \end{cases}
# $$
# where $ \alpha $ is a hyperparameter that controls the value to which ELU saturates for negative inputs. Typically, $ \alpha $ is set to 1.
#
# <img src="https://i0.wp.com/sefiks.com/wp-content/uploads/2018/01/elu-derivative.png?resize=654%2C422&ssl=1" width="60%">
# <img src="https://tungmphung.com/wp-content/uploads/2020/02/elu_function.png" width="60%">
#
# **Characteristics:**
#
# 1. **Non-Linearity**: ELU is a non-linear activation function, which enables the network to model complex patterns in the data.
#
# 2. **Smoother Transition**: Unlike ReLU, which has a sharp change at $ x = 0 $, ELU provides a smooth and continuous transition between the negative and positive parts of the function. This smoothness can improve the learning dynamics and make optimization easier.
#
# 3. **Negative Values**: ELU allows negative values for inputs less than zero. This negative output helps to push the mean activation closer to zero, which can make the learning process more efficient by reducing bias shifts.
#
# 4. **Avoids the Dying ReLU Problem**: ELU helps mitigate the Dying ReLU problem by allowing negative values. Even for negative inputs, ELU outputs a non-zero value (except for large negative inputs where the output saturates to $-\alpha\$, which helps in maintaining active gradients and continued learning.
#
# 5. **Differentiable**: The ELU function is differentiable, which is essential for backpropagation during training.
#
# 6. **Output Range**: The output of ELU ranges from $-\alpha$ to $ \infty $. For positive inputs, the output is unbounded, similar to ReLU, while for negative inputs, the output saturates at $-\alpha$.
#
# 7. **Parameter $ \alpha $**: The parameter $ \alpha $ controls the saturation point for negative inputs. It is usually set to 1, but it can be tuned depending on the specific application.

# %% [markdown]
# #### 4. **Scaled Exponential Linear Unit (SELU):**
#  The Scaled Exponential Linear Unit (SELU) is an activation function designed to improve the learning dynamics of deep neural networks. It is a self-normalizing activation function, meaning it helps to maintain a mean of zero and unit variance throughout the network, which can significantly enhance training stability and performance. It is defined by the following formula:
#
#  $$
#     \text{SELU}(x) = \lambda \begin{cases}
#     x & \text{if } x > 0 \\
#     \alpha (e^x - 1) & \text{if } x \leq 0
#     \end{cases}
#  $$
#
# where $ \alpha $ and $ \lambda $ are predefined constants:
#    - Typically, $ \alpha \approx 1.6733 $
#    - Typically, $ \lambda \approx 1.0507 $
#
#
# <img src="https://miro.medium.com/v2/resize:fit:1400/1*4IEHWYphW2juRfbCJPQt_w.png" width="60%">
#
# **Characteristics:**
# 1. **Non-Linearity**: SELU is a non-linear activation function, which enables the network to capture complex patterns in the data.
#
# 2. **Self-Normalizing**: The primary advantage of SELU is its self-normalizing property. It helps to maintain zero mean and unit variance throughout the layers of the network, which stabilizes the training process and allows for faster convergence.
#
# 3. **Negative Values**: Similar to ELU, SELU outputs negative values for negative inputs. This negative saturation helps to maintain zero-centered outputs, reducing bias shifts.
#
# 4. **Avoids the Dying ReLU Problem**: By allowing negative values and ensuring a non-zero gradient for all inputs, SELU helps to avoid the Dying ReLU problem, where neurons stop learning due to zero gradients.
#
# 5. **Differentiable**: The SELU function is differentiable, making it compatible with gradient-based optimization methods such as backpropagation.
#
# 6. **Output Range**: The output of SELU ranges from $ \lambda \alpha (e^x - 1) $ for negative inputs to $ \lambda x $ for positive inputs.
